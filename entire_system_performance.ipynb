# %%
# create a list of words from wikipedia and claims dev
add them to worddict
train models again, helaas

# %%
# wikidatabase
import os
import shutil
import json
import spacy 

from wiki_database import WikiDatabaseSqlite

import config

from utils_doc_results_db import get_tag_2_id_dict_unigrams

# %%
path_wiki_pages = os.path.join(config.ROOT, config.DATA_DIR, config.WIKI_PAGES_DIR, 'wiki-pages')
path_wiki_database_dir = os.path.join(config.ROOT, config.DATA_DIR, config.DATABASE_DIR)

wiki_database = WikiDatabaseSqlite(path_wiki_database_dir, path_wiki_pages)

nlp = spacy.load('en', disable=["parser", "ner"])
# Out:
# wiki_database
# /mnt/01_thesis/01_code/fever/_01_data/_03_database
# - Load existing settings file
# - Load title dictionary

# %%
from tqdm import tnrange
nr_wiki_pages = wiki_database.settings['nr_wikipedia_pages']
# nr_wiki_pages
# nr_wiki_pages = 6
vocab = []
for page_id in tnrange(nr_wiki_pages):
    text = wiki_database.get_text_from_id(page_id)
    splitted_text = text.split()
    vocab += splitted_text
    if (page_id % 100000 == 0) or (page_id == nr_wiki_pages-1):
        vocab = list(set(vocab))
# Out:
# HBox(children=(IntProgress(value=0, max=5416536), HTML(value='')))

# %%
vocab_claim = [word for word in vocab]

# %%
path_claims = '/mnt/01_thesis/01_code/ESIM/tmp2/document_retrieval'
nr_claims = 19998
for claim_nr in tqdm(range(nr_claims)):
    path_claim = os.path.join(path_claims, str(claim_nr) + '.json')
    claim_dict = dict_load_json(path_claim)
    text = claim_dict['claim']
    splitted_text = text.split()
    vocab_claim += splitted_text
vocab_claim = list(set(vocab_claim))
# Out:
# 100%|██████████| 19998/19998 [00:01<00:00, 14079.61it/s]

# %%
from utils_db import dict_save_json
path_save = 'word_list_wiki_claim.json'
dict_vocab = {}
dict_vocab['vocab'] = vocab_claim
dict_save_json(dict_vocab, path_save)
# Out:
# overwriting file: word_list_wiki_claim.json

# %%
import os
from utils_db import dict_load_json
path_claims = '/mnt/01_thesis/01_code/ESIM/tmp2/document_retrieval'
claim_nr=14
path_claim = os.path.join(path_claims, str(claim_nr) + '.json')
claim_dict = dict_load_json(path_claim)
claim_dict
# Out:
# {'id': 105095,
#  'verifiable': 'VERIFIABLE',
#  'label': 'SUPPORTS',
#  'claim': 'Nicholas Brody is a character on Homeland.',
#  'evidence': [[[123414, 137856, 'Nicholas Brody', 1]],
#   [[123414, 137857, 'Nicholas Brody', 4],
#    [123414, 137857, 'Carrie Mathison', 0],
#    [123414, 137857, 'Carrie Mathison', 2]]],
#  'docs_selected': [2553706,
#   3528440,
#   732975,
#   2507446,
#   4019142,
#   3351919,
#   1321538,
#   2247353,
#   2388061,
#   794106,
#   2179759,
#   2226974,
#   794475,
#   2205402,
#   2225651,
#   3543414,
#   3478834,
#   811081,
#   862151,
#   4785169],
#  'results': {'e_score': 0.6666666666666666,
#   'f_score': 1,
#   'e_score_labelled': 1,
#   'f_score_labelled': 1},
#  'document_retrieval': {'4785169': {'3': {'claim': {'tag_list': [17,
#       12,
#       12,
#       16,
#       6,
#       8,
#       1,
#       12,
#       13,
#       17],
#      'word_list': [2, 4753, 8208, 11, 9, 104, 22, 5008, 5, 3],
#      'exact_match_list': [0, 2, 9, 7, 6, 3, 8, 4, 5, 1]},
#     'document': {'tag_list': [17,
#       6,
#       8,
#       16,
#       16,
#       1,
#       12,
#       12,
#       13,
#       12,
#       13,
#       12,
#       1,
#       9,
#       13,
#       17],
#      'word_list': [2,
#       6,
#       61,
#       14,
#       668,
#       40,
#       1,
#       501,
#       4,
#       816,
#       4,
#       1828,
#       8,
#       208,
#       5,
#       3],
#      'exact_match_list': [0,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       74,
#       5,
#       1]}}}}}

# %%
from collections import Counter
list_words = vocab_claim
counts = Counter(list_words)
for i, word in enumerate(counts.most_common(num_words)):
    self.worddict[word[0]] = i + offset
# Out:
# Counter({'Servaea': 1,
#          'translatomes': 1,
#          'Wakhi/Urdu': 1,
#          'Finnish-German': 1,
#          'Furnishinoidea': 1,
#          'Хурошвили': 1,
#          'Burotu': 1,
#          'Eskol-e': 1,
#          'neurocytomas': 1,
#          'Schweigen': 1,
#          'headbangers': 1,
#          'Cicurels': 1,
#          '2:24.80': 1,
#          'Lémeret': 1,
#          '72.1.1': 1,
#          'Övdalian': 1,
#          'Leptosia': 1,
#          'Maḫlūf': 1,
#          'CONIAGRO': 1,
#          'گورابادي': 1,
#          'Soloff': 1,
#          'حبچيه': 1,
#          '1599-1667': 1,
#          'Parnaoz': 1,
#          'Kerala.This': 1,
#          'inert': 1,
#          'intermédiaire': 1,
#          'Mendeleev': 1,
#          'Ai-bim-pa': 1,
#          'chlorosuccinic': 1,
#          '3.471074': 1,
#          'Saksawaman': 1,
#          'Robinet': 1,
#          'CH2CH2N': 1,
#          'iˈβɛɾiku': 1,
#          'Dongtsab': 1,
#          'Hamilton-Standard': 1,
#          'Dolabaille': 1,
#          'mja': 1,
#          'Meccanotecnica': 1,
#          'opinion/commentary': 1,
#          '.6.2': 1,
#          'appliqué-pattern': 1,
#          'presettlement': 1,
#          'c1913': 1,
#          'masyura': 1,
#          'vatswaf': 1,
#          '1xEV-DO': 1,
#          '22,399': 1,
#          'Cranioceras': 1,
#          'Abul-Abbas': 1,
#          'DataCAD': 1,
#          'tachi-waza': 1,
#          'Richmondian': 1,
#          'Avuvu': 1,
#          'Lucetia': 1,
#          '3-hydroxyacyl': 1,
#          'Regattabar': 1,
#          'Pugilese': 1,
#          'Bronchos/Naps': 1,
#          '簡': 1,
#          'Rly': 1,
#          'Broec': 1,
#          'Jan-Eric': 1,
#          'Zhumabay': 1,
#          'al-Aqabah': 1,
#          'hosei': 1,
#          'Pallada-class': 1,
#          'Ellusionist': 1,
#          'Himmaste': 1,
#          'Rogê': 1,
#          'ISBe': 1,
#          'theogeny': 1,
#          'Eifel-Rur': 1,
#          'gachassini': 1,
#          'Yumeko': 1,
#          'Kechaari': 1,
#          'Taiwan/Formosa': 1,
#          'jv16': 1,
#          'paramhansas': 1,
#          'FWRM': 1,
#          'Salí': 1,
#          'Beruda': 1,
#          'prizewinner': 1,
#          'Swaya': 1,
#          'EISP': 1,
#          'hydrogenate': 1,
#          'V12-powered': 1,
#          'Nirdlinger': 1,
#          'orientalim': 1,
#          'Bythwood': 1,
#          'Popular/People': 1,
#          'inchcape': 1,
#          'Nopel': 1,
#          'DuttonEdward': 1,
#          'Moshian': 1,
#          '1420-1423': 1,
#          'Kräuterkäse-Fabrikanten': 1,
#          'đới': 1,
#          'Fokovci': 1,
#          'Cowmeadow': 1,
#          'dual-bladed': 1,
#          'amɑ̃': 1,
#          'wound/malady': 1,
#          'T8519': 1,
#          'Winge': 1,
#          '1FM': 1,
#          'pMOS': 1,
#          'Yaipén': 1,
#          'Erbstadt': 1,
#          'PYc-47': 1,
#          'KOI-7296': 1,
#          'Comberbach': 1,
#          'Temani': 1,
#          'OrigRegion': 1,
#          'Bromofluorocarbon': 1,
#          'PARTICULARS': 1,
#          'Opia': 1,
#          'awdlau': 1,
#          'Mahajaran': 1,
#          'Bosch-Omori': 1,
#          'mSi-bir': 1,
#          'back-migration': 1,
#          'Ólafr': 1,
#          'Cambodia.Close': 1,
#          'Anziani': 1,
#          'tal-Ħarba': 1,
#          'ʒiɲak': 1,
#          'SCN2A1': 1,
#          '5H-dibenzo': 1,
#          'Taaiboschspruit': 1,
#          'ryfA': 1,
#          'Lousie': 1,
#          'xmap': 1,
#          'Ghostball': 1,
#          'WWJS-CD': 1,
#          '10,168': 1,
#          'گونه': 1,
#          'Gocławice': 1,
#          'Panskov': 1,
#          'Sauli': 1,
#          'fulvosquamella': 1,
#          'Mandelic': 1,
#          'Hautesvignes': 1,
#          'Rheingauer': 1,
#          'HeE': 1,
#          'Shellie': 1,
#          'Ekkeharding': 1,
#          'Fothud': 1,
#          'Maanavatvam': 1,
#          'C1Pro': 1,
#          'future-forward': 1,
#          'Paradise-Benowa': 1,
#          'Medovo': 1,
#          'Bucksbarg': 1,
#          'Waselabad': 1,
#          'Mijtens': 1,
#          'Piasi': 1,
#          '木造竜燈鬼立像': 1,
#          'Greenbloom': 1,
#          'اورنه': 1,
#          '116,583': 1,
#          'géopolitiques': 1,
#          'Olex': 1,
#          'ITGB7': 1,
#          'beatSBUC': 1,
#          'Buttyin': 1,
#          'Cleophers': 1,
#          'Чорноморський': 1,
#          'tʃiːˈtʃɛn': 1,
#          'Yīnyángjiā': 1,
#          '10,30,00,000': 1,
#          'K-Rod': 1,
#          'BiMA': 1,
#          'Pleonaste': 1,
#          'Itirapuã': 1,
#          'Furuseki': 1,
#          'دادة': 1,
#          'Namazgyakh': 1,
#          'Film-concert': 1,
#          'Kajuga': 1,
#          'Epoha': 1,
#          'Elaphrosuchus': 1,
#          '1923-1942': 1,
#          'Melbourne.http': 1,
#          'zori': 1,
#          'SR-G10000': 1,
#          '134,720': 1,
#          'maraklah': 1,
#          '1836-43': 1,
#          'Montégut-en-Couserans': 1,
#          'Гли́кберг': 1,
#          'Rybatskoye': 1,
#          'callisoni': 1,
#          'Iodyrite': 1,
#          'EMV-CAP': 1,
#          '2-Chloropropionic': 1,
#          '67:26': 1,
#          'Talinovac': 1,
#          'C10H14O2': 1,
#          'too-quick': 1,
#          'patriotic/anti-war': 1,
#          '南方国际人才研究院': 1,
#          'Bodereau': 1,
#          'Schraubglasdeckel': 1,
#          'Battina': 1,
#          'Prosity': 1,
#          'Bakerella': 1,
#          'Touki': 1,
#          'Hayseeds': 1,
#          'semilanuta': 1,
#          'Menaucourt': 1,
#          "L'agression": 1,
#          'gezien': 1,
#          'WLIT': 1,
#          'Shezuri': 1,
#          '1464-1529': 1,
#          'Kotli-Rawalpindi': 1,
#          'anti-fur': 1,
#          'Himmelen': 1,
#          'lə.mɛʁ.sje': 1,
#          'powerpack': 1,
#          'Paniyiri': 1,
#          'CoreIntegrator': 1,
#          'Avodath': 1,
#          'Isakawarsa': 1,
#          'Pietrzejowice': 1,
#          'paulianella': 1,
#          '4:01.35': 1,
#          'Shramok': 1,
#          '642.0': 1,
#          'grand-prix': 1,
#          '.98,50,000': 1,
#          'pharetropis': 1,
#          'массовые': 1,
#          'Suffian': 1,
#          'arzˈmɑsˤɾ': 1,
#          'NEuhof': 1,
#          'kurash': 1,
#          'A.McQuaide': 1,
#          'Kawiley': 1,
#          '129,850': 1,
#          'Sandié': 1,
#          'Mineman': 1,
#          'mini-hysteria': 1,
#          'rois': 1,
#          'club.and': 1,
#          'Yonjigen': 1,
#          'low-information': 1,
#          'humerofulvus': 1,
#          'Sunaina': 1,
#          'SMKSMS': 1,
#          'RGX-121DM': 1,
#          'Palkān-e': 1,
#          '68mm': 1,
#          'Хоро́льский': 1,
#          'Yogayog': 1,
#          'Roth-directed': 1,
#          'Đàm': 1,
#          'Pikoil': 1,
#          'Völkermord': 1,
#          'ጽሂመሊስ': 1,
#          'Zolotonoshka': 1,
#          'Aradul': 1,
#          'Jasini': 1,
#          'Prathamādhyāya': 1,
#          'the.legend': 1,
#          'Roses-drummer': 1,
#          'Arusiensis': 1,
#          '15,683': 1,
#          '9,947': 1,
#          'Miguel-Luz': 1,
#          'guitar/keys': 1,
#          'crenulipennis': 1,
#          '2-related': 1,
#          'Defāʿ-ye': 1,
#          'โลกาวิทย์': 1,
#          'YMCA-Scouts': 1,
#          'Armagnostus': 1,
#          'skew-T': 1,
#          'Hatchling': 1,
#          'KNVN': 1,
#          'Scratchmann': 1,
#          '8/3-C': 1,
#          'Jamepally': 1,
#          'SNAPC2': 1,
#          'c1661': 1,
#          'www.testdifferent.com': 1,
#          'Timmakka': 1,
#          'Кизяков': 1,
#          'Caralia': 1,
#          'ერეკლე': 1,
#          'Polecat-Mink': 1,
#          'UKZAMBIANS': 1,
#          'multidatabase': 1,
#          'Akalay': 1,
#          'ridge-ridge-ridge': 1,
#          'waking-state-ego': 1,
#          'Troppo': 1,
#          'Blackboards': 1,
#          'K03BZ': 1,
#          'Jianzhao': 1,
#          'Dzhankoy-Kherson': 1,
#          'Adjan': 1,
#          'Cc': 1,
#          'neurotechnologies': 1,
#          'Sambiria': 1,
#          'DD-24': 1,
#          'Αμαθα': 1,
#          'Malavoglia': 1,
#          'FOLs': 1,
#          'Monstertrux': 1,
#          'Hommel-Etamic': 1,
#          'pre-hoop': 1,
#          'Tuliameni': 1,
#          'WQBB': 1,
#          'wage-hour': 1,
#          'WGAs': 1,
#          'dryocremna': 1,
#          'sandpit': 1,
#          'Mindbreaker': 1,
#          'Anno/Killers': 1,
#          '523.06': 1,
#          '1876-1908': 1,
#          'Innox': 1,
#          'cucullate-lobed': 1,
#          'Sakska': 1,
#          'tɪˈrɛl': 1,
#          'Farset': 1,
#          'Rab11a': 1,
#          'x89': 1,
#          'Aghdamkend': 1,
#          'Deelite': 1,
#          'tragema': 1,
#          'pliński': 1,
#          'Artsrun': 1,
#          'axšaēna': 1,
#          'Fourteenth-century': 1,
#          'Hathakauli': 1,
#          'lativalvaris': 1,
#          'NUS/NTU': 1,
#          'Policena': 1,
#          'Hennaru': 1,
#          'Bar-B': 1,
#          'punkie': 1,
#          'cryptophyte': 1,
#          'Rügensche': 1,
#          'Islands.There': 1,
#          'Dabhou': 1,
#          'Amblesthis': 1,
#          'Wavelet-related': 1,
#          'Pridefest': 1,
#          'App-a-Rama': 1,
#          'Loricosaurus': 1,
#          '12,731': 1,
#          'Čatežu': 1,
#          'Дибиров': 1,
#          'Anton-Wallich-Clifford': 1,
#          'Jazz/4': 1,
#          'ice-yacht': 1,
#          'Nadan': 1,
#          'Iopamiro': 1,
#          '1908died': 1,
#          'Kasteels': 1,
#          'Linaburg': 1,
#          'tyvtɯˈva': 1,
#          'anti-sweet': 1,
#          'Standardsville': 1,
#          'Frost.': 1,
#          'Kanaaldijk': 1,
#          'Voskehat': 1,
#          'Amoebe': 1,
#          'lʌv': 1,
#          'Κυνοσούρα': 1,
#          'Lawa': 1,
#          'scst': 1,
#          'Danforths': 1,
#          'pachyrhynchus': 1,
#          'Bort-le-Comte': 1,
#          'Molenillo': 1,
#          'Al-Kilh': 1,
#          'ചാര': 1,
#          'entzat': 1,
#          'PERCOMPLETE': 1,
#          'rib-like': 1,
#          'ink': 1,
#          'Veshniy': 1,
#          'Evropaiki': 1,
#          'Turvasu': 1,
#          'pro-Fascist': 1,
#          'wasagrée': 1,
#          'Haatst': 1,
#          'HT-28': 1,
#          'interino': 1,
#          'dɨːð': 1,
#          'Гривочки': 1,
#          'Turbius': 1,
#          'GODDESSES': 1,
#          'Yonhi': 1,
#          'tuˈliʂkuf': 1,
#          'Delta-class': 1,
#          'Матесеи': 1,
#          'ptychasthena': 1,
#          'pszesz': 1,
#          'Yeeshan': 1,
#          'Koukouvista': 1,
#          'ناشيونال': 1,
#          'stara-kraś': 1,
#          'Gramsh': 1,
#          'E200': 1,
#          'Wenona': 1,
#          '16354': 1,
#          '1637-1704': 1,
#          'tharpa': 1,
#          'Wognsen': 1,
#          'Papratna': 1,
#          'BLIS.F.M': 1,
#          'pseudocaninus': 1,
#          'cyane': 1,
#          'Deoxyribose-phosphate': 1,
#          'Cornouayl': 1,
#          'most-definitive': 1,
#          'Zdv': 1,
#          'NPRL2': 1,
#          'merumontanus': 1,
#          'INES-4': 1,
#          'Greenland': 1,
#          'group-mandated': 1,
#          'Darrāȳ': 1,
#          'Maaslands': 1,
#          'Coulaudon': 1,
#          'bondless': 1,
#          'Kurukulasuriya': 1,
#          'Kapachira': 1,
#          'XZ439': 1,
#          '1950-1998': 1,
#          'Tcherny': 1,
#          'Rougon': 1,
#          'chartaboma': 1,
#          'salve': 1,
#          'Beznazwa': 1,
#          'Krecsunesd': 1,
#          'mannapuuro': 1,
#          '250g': 1,
#          'river-land': 1,
#          'Dayoub': 1,
#          'OTs-01': 1,
#          '1636-1696': 1,
#          'anti-estrogen': 1,
#          'subcinnamomea': 1,
#          'Hofz': 1,
#          'Khalīfeh-ye': 1,
#          'Ighmorlū': 1,
#          'CaseManagement': 1,
#          'ADP-dependent-medium-chain-acyl-CoA': 1,
#          'armanite': 1,
#          'Kashidakari': 1,
#          '22nd-Century': 1,
#          'β-galctosidase': 1,
#          'Synncarpy': 1,
#          "H'Doubler": 1,
#          'СТАРТ': 1,
#          'Henican': 1,
#          'end-of-office': 1,
#          'C18H22N2O2': 1,
#          'insectivorans': 1,
#          'Emiratization': 1,
#          'Bănceşti': 1,
#          'Tristars': 1,
#          'Purcell-FitzGerald': 1,
#          'PSfrag': 1,
#          'Zypper': 1,
#          'Giacomense': 1,
#          'Deleske': 1,
#          'Cilrhiw': 1,
#          'Azzougarh': 1,
#          'TJOS': 1,
#          'Ḩasam': 1,
#          'Epps': 1,
#          'Rech.f': 1,
#          'n-ṣ-r': 1,
#          '11-5-1': 1,
#          'Grenville-Wells': 1,
#          'kopovi': 1,
#          'Tingatinga': 1,
#          '1-600': 1,
#          'art-therapy': 1,
#          'oneknife': 1,
#          '23832': 1,
#          'sheep-herder': 1,
#          'assessment/intervention': 1,
#          'بانہال': 1,
#          'Regreen': 1,
#          'AKTU': 1,
#          'AskMD': 1,
#          'Tortuosa': 1,
#          'CREATED': 1,
#          'BentleyForbes': 1,
#          'Cajtlin': 1,
#          '1900-1937': 1,
#          'Sikhae': 1,
#          'Tǔhuà': 1,
#          '37.8': 1,
#          'Kirvin': 1,
#          'Maharajji': 1,
#          '-681': 1,
#          'office/hospital': 1,
#          'enneahedron': 1,
#          'ServON': 1,
#          'Dattajivo': 1,
#          'single-asset': 1,
#          'Sulkow': 1,
#          'Tearce-97': 1,
#          'HHRO': 1,
#          'Beta-galactosidases': 1,
#          'WFRV-TV': 1,
#          'ericjhellergallery.com': 1,
#          'Veissière': 1,
#          'Celtiagh': 1,
#          'Junction-Rotherwood': 1,
#          'ɐxˈmadəvʲɪtɕ': 1,
#          '熠熠星光总动员': 1,
#          'NATO-HELICOPTER': 1,
#          'vapour-pressure': 1,
#          'Kopyt': 1,
#          'Karşılaması': 1,
#          'then-6th': 1,
#          'Oldtymers': 1,
#          'Marsilly': 1,
#          'EMPC': 1,
#          'Silfvast': 1,
#          'cavanas': 1,
#          'singer/composer/producer': 1,
#          'Cloan': 1,
#          'Demofest': 1,
#          'UEK': 1,
#          'Kundrathur': 1,
#          'Profitt': 1,
#          'Tharavadinte': 1,
#          'ouai': 1,
#          'D-Monroe': 1,
#          '27,269': 1,
#          'Zohara': 1,
#          'Neo-Luddite': 1,
#          'Fluid-jet': 1,
#          'anagestone': 1,
#          'Chakodi': 1,
#          'Khotov': 1,
#          'Tiflis-Alexandropol': 1,
#          'Czechosłowacji': 1,
#          'sealers': 1,
#          'KOTOR': 1,
#          'verais': 1,
#          '12-m': 1,
#          'ˈʁoːtɐmʊnt': 1,
#          'boo-boys': 1,
#          'Slovinska': 1,
#          '1559-1623': 1,
#          'Decapitones': 1,
#          'iDataCool': 1,
#          'Atzilus': 1,
#          'Vrapice': 1,
#          'Hah-kah': 1,
#          'Jean': 1,
#          'WHFX': 1,
#          '2,285,067': 1,
#          'BLSE': 1,
#          'grundlovgivende': 1,
#          'dinitro-2': 1,
#          'Prêt-à-Porter': 1,
#          'Re-LIVE': 1,
#          'Buccahad': 1,
#          'desertae': 1,
#          'Roboré': 1,
#          'Soulwax': 1,
#          'Corfu-island': 1,
#          'Planinić': 1,
#          'roughneck': 1,
#          'Regiments': 1,
#          'Anizan': 1,
#          'Румъния': 1,
#          'Norn-speakers': 1,
#          'За́падно': 1,
#          'Nprth': 1,
#          'Rajbaug': 1,
#          'GMTA': 1,
#          'Abagadasset': 1,
#          'Parkers': 1,
#          'Halehomaha': 1,
#          'Middleweek': 1,
#          '64-88': 1,
#          'OnForce': 1,
#          'مخبز': 1,
#          'Allegorically': 1,
#          'Zahkarov': 1,
#          'Strazvrid': 1,
#          '5,947,213': 1,
#          'Europaeus': 1,
#          'Chornoriky': 1,
#          'Tiegelmann': 1,
#          'mâu': 1,
#          'Cochran': 1,
#          '0739': 1,
#          'earth-integrated': 1,
#          'utilitarianism': 1,
#          'қуу': 1,
#          'A49/B4370': 1,
#          '174818': 1,
#          'Enarg': 1,
#          'suprapellis': 1,
#          'Qaramqũl': 1,
#          'Ulgenes': 1,
#          'constellationof': 1,
#          '河俊任': 1,
#          'Tabscoob': 1,
#          'Pork': 1,
#          'Ia3m': 1,
#          'Bandasuma': 1,
#          'Ratafia': 1,
#          'Imegwu': 1,
#          'Microweiseinae': 1,
#          'Jirnsum': 1,
#          'Fulsztyn': 1,
#          'Solimani': 1,
#          'biscuit-crumb': 1,
#          '0896-3207': 1,
#          'Vielfalt': 1,
#          'Loena': 1,
#          'Diapalpus': 1,
#          '1847-1858': 1,
#          '267.183444': 1,
#          'Jehan.Lyrics': 1,
#          '05580': 1,
#          'TIDEL': 1,
#          'all-clear': 1,
#          'Jafarov': 1,
#          'dogsitters': 1,
#          'whitelockiana': 1,
#          'Mārfi': 1,
#          'Elissery': 1,
#          'Unnilseptium': 1,
#          'Kāpiti': 1,
#          'Saint-Seurin-de-Prats': 1,
#          'Alphonsa': 1,
#          'Barnali': 1,
#          '755-97': 1,
#          '245-252': 1,
#          'Bangkokbiznews': 1,
#          'Mauborget': 1,
#          'Natsuzuki': 1,
#          'Hēnare': 1,
#          'OAO-2': 1,
#          'VCPRD': 1,
#          'Canev': 1,
#          'Botifoll': 1,
#          'Estoniops': 1,
#          'Neomodus': 1,
#          'silphion': 1,
#          'Baruny': 1,
#          '2-205': 1,
#          'Unamerican': 1,
#          'Clonygowan': 1,
#          'Vinício': 1,
#          'Nopca': 1,
#          'Fiakas': 1,
#          'اوگون': 1,
#          'Qandahār-nāma': 1,
#          'Huangpiqiang': 1,
#          'Mzieme': 1,
#          'Zaparoana': 1,
#          'עילית': 1,
#          'Kavelan-e': 1,
#          'Lufus': 1,
#          'Plasmodium': 1,
#          'Fictel': 1,
#          'fifth-class': 1,
#          'Roltdalen': 1,
#          'Chloros': 1,
#          'Reikhi': 1,
#          'Rhabdocoela': 1,
#          'Achingale': 1,
#          'Yerushalayim/Al': 1,
#          'Kiraron': 1,
#          'Dolagovinda': 1,
#          'teen-age': 1,
#          'assassin': 1,
#          'Ellence': 1,
#          'Taschenbergpalais': 1,
#          'Lacue': 1,
#          'PQAs': 1,
#          '1637-I': 1,
#          'nacnac': 1,
#          'WWll': 1,
#          'weissgrundige': 1,
#          'Villicaña': 1,
#          'Z-Gang': 1,
#          'nonfermenters': 1,
#          'UWE-2': 1,
#          'capability-providing': 1,
#          'PANAM': 1,
#          'TRATS': 1,
#          'Мусоргский': 1,
#          'Powell-Reed': 1,
#          'F-300': 1,
#          'Shikadi': 1,
#          'Westarctica': 1,
#          'Π02-theorems': 1,
#          'Morkovsky': 1,
#          'rasande': 1,
#          'Sachs-Osher': 1,
#          'Erasmos': 1,
#          'Tharika': 1,
#          'Linghorn': 1,
#          '2-6-92': 1,
#          'Carlomann': 1,
#          'Celle-les-Bordes': 1,
#          'Kokroman': 1,
#          'Relojero': 1,
#          'D.O.C.': 1,
#          'Muarem': 1,
#          'interthalamic': 1,
#          'XHRHI-FM': 1,
#          'Corendon': 1,
#          'Al-Andalusiya': 1,
#          'Scario': 1,
#          'Chlorides': 1,
#          'philia': 1,
#          'Codementor': 1,
#          'additionally': 1,
#          'Burke': 1,
#          'Gallimore': 1,
#          'three-seeded': 1,
#          '945,299': 1,
#          'GAS-specific': 1,
#          'off-airport': 1,
#          'Κλύσωνυμος': 1,
#          'Eyfi': 1,
#          'SolSuite': 1,
#          'ˈɪŋmar': 1,
#          'Amaryngkëidês': 1,
#          '296,739': 1,
#          'Sunflour': 1,
#          'Kaalazhaga': 1,
#          'ADE': 1,
#          'Annamitta': 1,
#          'Panales': 1,
#          'clusterheads': 1,
#          '0-312-42171-0': 1,
#          'Shafiz': 1,
#          'A972': 1,
#          'Krasovska': 1,
#          'Wekusko': 1,
#          '18627': 1,
#          'YMS-215': 1,
#          'Linnéenne': 1,
#          '84e': 1,
#          'GloboEsporte.com': 1,
#          '10-Shi': 1,
#          'fishrock': 1,
#          '18,876': 1,
#          'motorcycle-fender': 1,
#          "L'Embarras": 1,
#          'Cuchiniș': 1,
#          'Sultartangastöð': 1,
#          '200-second': 1,
#          'scoutfor': 1,
#          'Fief': 1,
#          'W60-only': 1,
#          'Isomma': 1,
#          'nonjurant': 1,
#          'ActUp': 1,
#          'shortbreat-type': 1,
#          'źuga': 1,
#          'Froy': 1,
#          'taIńska': 1,
#          'Kausbekovich': 1,
#          'boulodromes': 1,
#          'Scaglia': 1,
#          'Cydewain': 1,
#          'semicognata': 1,
#          'carpincho': 1,
#          'Zenret': 1,
#          'بهادرئ': 1,
#          'nuclear-blasted': 1,
#          '1110s': 1,
#          'safety-word': 1,
#          'selffinancing': 1,
#          'Grapow': 1,
#          'Chrysolaena': 1,
#          'TNT/TBS': 1,
#          'Dougla': 1,
#          'Souakri': 1,
#          'Атомэнергопром': 1,
#          'divyā́': 1,
#          'Stazak': 1,
#          'Φίλιπποι': 1,
#          'Ghosks': 1,
#          'Noemfoer': 1,
#          'two-generator': 1,
#          '8307': 1,
#          'Clementino': 1,
#          'lonek': 1,
#          'Ajinyaz': 1,
#          'Nebbi': 1,
#          'nɔːrˈθʌmbərlənd': 1,
#          'Rajadamnern': 1,
#          'PHOTOESPAÑA': 1,
#          'intercepting': 1,
#          'Desmoglein-4': 1,
#          'Lethent': 1,
#          'Heegoo': 1,
#          'Zitatenschatz': 1,
#          'man-trailer': 1,
#          'Maestro/Cirrus': 1,
#          'Krystalak': 1,
#          'non-Nauruan': 1,
#          'UNMACC': 1,
#          'Masjid-Al-Aqsa': 1,
#          'protozoan': 1,
#          'WeSET': 1,
#          '1054th': 1,
#          'Byngham': 1,
#          'Richsquare': 1,
#          'Recaido': 1,
#          '10001110101': 1,
#          'Stormwatch': 1,
#          'balkuf': 1,
#          '20,000-square-foot': 1,
#          'SAFMAR': 1,
#          'Sahkanaga': 1,
#          'waterrequested': 1,
#          'MC-101': 1,
#          'wall-run': 1,
#          'Hablitz': 1,
#          'honum': 1,
#          'ŋʷˤa': 1,
#          'Anyer-Labuan': 1,
#          'Argyrokastro': 1,
#          'gray-blue': 1,
#          'Ambrosano': 1,
#          'intrépides': 1,
#          'Tementhes': 1,
#          'Raymondo': 1,
#          'Andonyadis': 1,
#          'Tripps': 1,
#          'Shāl': 1,
#          'Condylidium': 1,
#          'Entrata': 1,
#          'Pookunhikoya': 1,
#          'D31b': 1,
#          'Kővágószőlős': 1,
#          'solbon': 1,
#          'guardian-angel': 1,
#          'Thr11': 1,
#          'Ertzica': 1,
#          'Station-Shromojibi': 1,
#          'seasides': 1,
#          'Sevskoye': 1,
#          'Clowry': 1,
#          'Thukhar': 1,
#          'Ueckermünde': 1,
#          'Nikšićka': 1,
#          'Ton-Pentre': 1,
#          'County-National': 1,
#          'Moneygall': 1,
#          'Rājyāñchā': 1,
#          'Pinders': 1,
#          'seyriganus': 1,
#          'Otaniemen': 1,
#          'tararua': 1,
#          'rs12970134': 1,
#          '1324/5': 1,
#          'X960': 1,
#          'ploughteams': 1,
#          'Paerformace': 1,
#          'non-miraculous': 1,
#          '136.05': 1,
#          'Tolour': 1,
#          'S-VYASA': 1,
#          "Y's": 1,
#          'C12195': 1,
#          'McHappy': 1,
#          'molator': 1,
#          'Salījān': 1,
#          'księżną': 1,
#          'filterless': 1,
#          'комітет': 1,
#          'presoaking': 1,
#          'Megatel': 1,
#          'ܨܠܘܬܐ': 1,
#          'maɪˈæmiːzbərg': 1,
#          'SouthernLINC': 1,
#          'Weinblatt': 1,
#          'dainty-looking': 1,
#          'معاونت': 1,
#          'Sundowe': 1,
#          'previouslye': 1,
#          'SYSOPS': 1,
#          'periwigs': 1,
#          'Irishenco': 1,
#          'al-Qazwini': 1,
#          'Trentepohlia': 1,
#          'Vinassan': 1,
#          'Rhypotoses': 1,
#          'collectivization': 1,
#          'RHAM/1': 1,
#          'NAAT-II': 1,
#          'Heeriye': 1,
#          'N.tabacum': 1,
#          'Choza': 1,
#          'Alfāūūt': 1,
#          'pale-flecked': 1,
#          'Riidamäe': 1,
#          'Тодорчев': 1,
#          '7919601': 1,
#          'ماهنامه': 1,
#          'Surgeonfishes': 1,
#          'DBs': 1,
#          'Shemer': 1,
#          'sucrose-glucan': 1,
#          'Baciocco': 1,
#          '41stGolden': 1,
#          'Rochebaudin': 1,
#          'EVENING': 1,
#          'antikhrist': 1,
#          'Arattana': 1,
#          '2018m': 1,
#          'Vaudreuille': 1,
#          '16Z': 1,
#          'Isoetopsida': 1,
#          '中国武术': 1,
#          'Kollerschlag': 1,
#          'Ex-Stratovarius': 1,
#          'zero-issue': 1,
#          'HASCO': 1,
#          '6,885': 1,
#          'GOKUL.A': 1,
#          'Jevišovice': 1,
#          'Sakihisa': 1,
#          'gelatinase-associated': 1,
#          '1921-1953': 1,
#          'Paramorbia': 1,
#          'Maraviev': 1,
#          'silver-plating': 1,
#          'cyanetron': 1,
#          'MuLab': 1,
#          'Amoenus': 1,
#          'Bathiste': 1,
#          'Венков': 1,
#          'stara-kośće1l': 1,
#          'Liulf': 1,
#          'Kvitfjell': 1,
#          '58P/Jackson-Neujmin': 1,
#          'Natronobacterium': 1,
#          'ctenoneurus': 1,
#          'Iaccaci': 1,
#          'CCOA': 1,
#          'McPark': 1,
#          'E-CDs': 1,
#          'Methofuran': 1,
#          'Barduń': 1,
#          'Prugovac': 1,
#          'Bangaeira': 1,
#          'Chahardangi': 1,
#          'RONIN': 1,
#          '24-1Lost': 1,
#          '28,665': 1,
#          '9312': 1,
#          'logothetes': 1,
#          'Maieco': 1,
#          'Auctum': 1,
#          'post-serialist': 1,
#          'svestvi': 1,
#          'cuahuitl': 1,
#          'bullae': 1,
#          'Starkbaum': 1,
#          'Takurō': 1,
#          'Kaaraku': 1,
#          'ninithi': 1,
#          'droids': 1,
#          'banaˈnaw': 1,
#          '周書': 1,
#          'Hakuoro': 1,
#          'Qalātū': 1,
#          'designatum': 1,
#          'Maduravoyal': 1,
#          'Gallenburg': 1,
#          'scarification': 1,
#          'Jingoism': 1,
#          'Charuvi': 1,
#          'end-products': 1,
#          '2,115,234': 1,
#          'Railroading': 1,
#          'ArtDaily': 1,
#          'DMMMSU-SLUC': 1,
#          'Drakšl': 1,
#          'Matsdotter': 1,
#          'MyEnvironment': 1,
#          'ski-yoo': 1,
#          'Zeitgeist': 1,
#          ...})

# %%
words = []
[words.extend([word]) for word in vocab_claim]
words
# Out:
# ['Servaea',
#  'translatomes',
#  'Wakhi/Urdu',
#  'Finnish-German',
#  'Furnishinoidea',
#  'Хурошвили',
#  'Burotu',
#  'Eskol-e',
#  'neurocytomas',
#  'Schweigen',
#  'headbangers',
#  'Cicurels',
#  '2:24.80',
#  'Lémeret',
#  '72.1.1',
#  'Övdalian',
#  'Leptosia',
#  'Maḫlūf',
#  'CONIAGRO',
#  'گورابادي',
#  'Soloff',
#  'حبچيه',
#  '1599-1667',
#  'Parnaoz',
#  'Kerala.This',
#  'inert',
#  'intermédiaire',
#  'Mendeleev',
#  'Ai-bim-pa',
#  'chlorosuccinic',
#  '3.471074',
#  'Saksawaman',
#  'Robinet',
#  'CH2CH2N',
#  'iˈβɛɾiku',
#  'Dongtsab',
#  'Hamilton-Standard',
#  'Dolabaille',
#  'mja',
#  'Meccanotecnica',
#  'opinion/commentary',
#  '.6.2',
#  'appliqué-pattern',
#  'presettlement',
#  'c1913',
#  'masyura',
#  'vatswaf',
#  '1xEV-DO',
#  '22,399',
#  'Cranioceras',
#  'Abul-Abbas',
#  'DataCAD',
#  'tachi-waza',
#  'Richmondian',
#  'Avuvu',
#  'Lucetia',
#  '3-hydroxyacyl',
#  'Regattabar',
#  'Pugilese',
#  'Bronchos/Naps',
#  '簡',
#  'Rly',
#  'Broec',
#  'Jan-Eric',
#  'Zhumabay',
#  'al-Aqabah',
#  'hosei',
#  'Pallada-class',
#  'Ellusionist',
#  'Himmaste',
#  'Rogê',
#  'ISBe',
#  'theogeny',
#  'Eifel-Rur',
#  'gachassini',
#  'Yumeko',
#  'Kechaari',
#  'Taiwan/Formosa',
#  'jv16',
#  'paramhansas',
#  'FWRM',
#  'Salí',
#  'Beruda',
#  'prizewinner',
#  'Swaya',
#  'EISP',
#  'hydrogenate',
#  'V12-powered',
#  'Nirdlinger',
#  'orientalim',
#  'Bythwood',
#  'Popular/People',
#  'inchcape',
#  'Nopel',
#  'DuttonEdward',
#  'Moshian',
#  '1420-1423',
#  'Kräuterkäse-Fabrikanten',
#  'đới',
#  'Fokovci',
#  'Cowmeadow',
#  'dual-bladed',
#  'amɑ̃',
#  'wound/malady',
#  'T8519',
#  'Winge',
#  '1FM',
#  'pMOS',
#  'Yaipén',
#  'Erbstadt',
#  'PYc-47',
#  'KOI-7296',
#  'Comberbach',
#  'Temani',
#  'OrigRegion',
#  'Bromofluorocarbon',
#  'PARTICULARS',
#  'Opia',
#  'awdlau',
#  'Mahajaran',
#  'Bosch-Omori',
#  'mSi-bir',
#  'back-migration',
#  'Ólafr',
#  'Cambodia.Close',
#  'Anziani',
#  'tal-Ħarba',
#  'ʒiɲak',
#  'SCN2A1',
#  '5H-dibenzo',
#  'Taaiboschspruit',
#  'ryfA',
#  'Lousie',
#  'xmap',
#  'Ghostball',
#  'WWJS-CD',
#  '10,168',
#  'گونه',
#  'Gocławice',
#  'Panskov',
#  'Sauli',
#  'fulvosquamella',
#  'Mandelic',
#  'Hautesvignes',
#  'Rheingauer',
#  'HeE',
#  'Shellie',
#  'Ekkeharding',
#  'Fothud',
#  'Maanavatvam',
#  'C1Pro',
#  'future-forward',
#  'Paradise-Benowa',
#  'Medovo',
#  'Bucksbarg',
#  'Waselabad',
#  'Mijtens',
#  'Piasi',
#  '木造竜燈鬼立像',
#  'Greenbloom',
#  'اورنه',
#  '116,583',
#  'géopolitiques',
#  'Olex',
#  'ITGB7',
#  'beatSBUC',
#  'Buttyin',
#  'Cleophers',
#  'Чорноморський',
#  'tʃiːˈtʃɛn',
#  'Yīnyángjiā',
#  '10,30,00,000',
#  'K-Rod',
#  'BiMA',
#  'Pleonaste',
#  'Itirapuã',
#  'Furuseki',
#  'دادة',
#  'Namazgyakh',
#  'Film-concert',
#  'Kajuga',
#  'Epoha',
#  'Elaphrosuchus',
#  '1923-1942',
#  'Melbourne.http',
#  'zori',
#  'SR-G10000',
#  '134,720',
#  'maraklah',
#  '1836-43',
#  'Montégut-en-Couserans',
#  'Гли́кберг',
#  'Rybatskoye',
#  'callisoni',
#  'Iodyrite',
#  'EMV-CAP',
#  '2-Chloropropionic',
#  '67:26',
#  'Talinovac',
#  'C10H14O2',
#  'too-quick',
#  'patriotic/anti-war',
#  '南方国际人才研究院',
#  'Bodereau',
#  'Schraubglasdeckel',
#  'Battina',
#  'Prosity',
#  'Bakerella',
#  'Touki',
#  'Hayseeds',
#  'semilanuta',
#  'Menaucourt',
#  "L'agression",
#  'gezien',
#  'WLIT',
#  'Shezuri',
#  '1464-1529',
#  'Kotli-Rawalpindi',
#  'anti-fur',
#  'Himmelen',
#  'lə.mɛʁ.sje',
#  'powerpack',
#  'Paniyiri',
#  'CoreIntegrator',
#  'Avodath',
#  'Isakawarsa',
#  'Pietrzejowice',
#  'paulianella',
#  '4:01.35',
#  'Shramok',
#  '642.0',
#  'grand-prix',
#  '.98,50,000',
#  'pharetropis',
#  'массовые',
#  'Suffian',
#  'arzˈmɑsˤɾ',
#  'NEuhof',
#  'kurash',
#  'A.McQuaide',
#  'Kawiley',
#  '129,850',
#  'Sandié',
#  'Mineman',
#  'mini-hysteria',
#  'rois',
#  'club.and',
#  'Yonjigen',
#  'low-information',
#  'humerofulvus',
#  'Sunaina',
#  'SMKSMS',
#  'RGX-121DM',
#  'Palkān-e',
#  '68mm',
#  'Хоро́льский',
#  'Yogayog',
#  'Roth-directed',
#  'Đàm',
#  'Pikoil',
#  'Völkermord',
#  'ጽሂመሊስ',
#  'Zolotonoshka',
#  'Aradul',
#  'Jasini',
#  'Prathamādhyāya',
#  'the.legend',
#  'Roses-drummer',
#  'Arusiensis',
#  '15,683',
#  '9,947',
#  'Miguel-Luz',
#  'guitar/keys',
#  'crenulipennis',
#  '2-related',
#  'Defāʿ-ye',
#  'โลกาวิทย์',
#  'YMCA-Scouts',
#  'Armagnostus',
#  'skew-T',
#  'Hatchling',
#  'KNVN',
#  'Scratchmann',
#  '8/3-C',
#  'Jamepally',
#  'SNAPC2',
#  'c1661',
#  'www.testdifferent.com',
#  'Timmakka',
#  'Кизяков',
#  'Caralia',
#  'ერეკლე',
#  'Polecat-Mink',
#  'UKZAMBIANS',
#  'multidatabase',
#  'Akalay',
#  'ridge-ridge-ridge',
#  'waking-state-ego',
#  'Troppo',
#  'Blackboards',
#  'K03BZ',
#  'Jianzhao',
#  'Dzhankoy-Kherson',
#  'Adjan',
#  'Cc',
#  'neurotechnologies',
#  'Sambiria',
#  'DD-24',
#  'Αμαθα',
#  'Malavoglia',
#  'FOLs',
#  'Monstertrux',
#  'Hommel-Etamic',
#  'pre-hoop',
#  'Tuliameni',
#  'WQBB',
#  'wage-hour',
#  'WGAs',
#  'dryocremna',
#  'sandpit',
#  'Mindbreaker',
#  'Anno/Killers',
#  '523.06',
#  '1876-1908',
#  'Innox',
#  'cucullate-lobed',
#  'Sakska',
#  'tɪˈrɛl',
#  'Farset',
#  'Rab11a',
#  'x89',
#  'Aghdamkend',
#  'Deelite',
#  'tragema',
#  'pliński',
#  'Artsrun',
#  'axšaēna',
#  'Fourteenth-century',
#  'Hathakauli',
#  'lativalvaris',
#  'NUS/NTU',
#  'Policena',
#  'Hennaru',
#  'Bar-B',
#  'punkie',
#  'cryptophyte',
#  'Rügensche',
#  'Islands.There',
#  'Dabhou',
#  'Amblesthis',
#  'Wavelet-related',
#  'Pridefest',
#  'App-a-Rama',
#  'Loricosaurus',
#  '12,731',
#  'Čatežu',
#  'Дибиров',
#  'Anton-Wallich-Clifford',
#  'Jazz/4',
#  'ice-yacht',
#  'Nadan',
#  'Iopamiro',
#  '1908died',
#  'Kasteels',
#  'Linaburg',
#  'tyvtɯˈva',
#  'anti-sweet',
#  'Standardsville',
#  'Frost.',
#  'Kanaaldijk',
#  'Voskehat',
#  'Amoebe',
#  'lʌv',
#  'Κυνοσούρα',
#  'Lawa',
#  'scst',
#  'Danforths',
#  'pachyrhynchus',
#  'Bort-le-Comte',
#  'Molenillo',
#  'Al-Kilh',
#  'ചാര',
#  'entzat',
#  'PERCOMPLETE',
#  'rib-like',
#  'ink',
#  'Veshniy',
#  'Evropaiki',
#  'Turvasu',
#  'pro-Fascist',
#  'wasagrée',
#  'Haatst',
#  'HT-28',
#  'interino',
#  'dɨːð',
#  'Гривочки',
#  'Turbius',
#  'GODDESSES',
#  'Yonhi',
#  'tuˈliʂkuf',
#  'Delta-class',
#  'Матесеи',
#  'ptychasthena',
#  'pszesz',
#  'Yeeshan',
#  'Koukouvista',
#  'ناشيونال',
#  'stara-kraś',
#  'Gramsh',
#  'E200',
#  'Wenona',
#  '16354',
#  '1637-1704',
#  'tharpa',
#  'Wognsen',
#  'Papratna',
#  'BLIS.F.M',
#  'pseudocaninus',
#  'cyane',
#  'Deoxyribose-phosphate',
#  'Cornouayl',
#  'most-definitive',
#  'Zdv',
#  'NPRL2',
#  'merumontanus',
#  'INES-4',
#  'Greenland',
#  'group-mandated',
#  'Darrāȳ',
#  'Maaslands',
#  'Coulaudon',
#  'bondless',
#  'Kurukulasuriya',
#  'Kapachira',
#  'XZ439',
#  '1950-1998',
#  'Tcherny',
#  'Rougon',
#  'chartaboma',
#  'salve',
#  'Beznazwa',
#  'Krecsunesd',
#  'mannapuuro',
#  '250g',
#  'river-land',
#  'Dayoub',
#  'OTs-01',
#  '1636-1696',
#  'anti-estrogen',
#  'subcinnamomea',
#  'Hofz',
#  'Khalīfeh-ye',
#  'Ighmorlū',
#  'CaseManagement',
#  'ADP-dependent-medium-chain-acyl-CoA',
#  'armanite',
#  'Kashidakari',
#  '22nd-Century',
#  'β-galctosidase',
#  'Synncarpy',
#  "H'Doubler",
#  'СТАРТ',
#  'Henican',
#  'end-of-office',
#  'C18H22N2O2',
#  'insectivorans',
#  'Emiratization',
#  'Bănceşti',
#  'Tristars',
#  'Purcell-FitzGerald',
#  'PSfrag',
#  'Zypper',
#  'Giacomense',
#  'Deleske',
#  'Cilrhiw',
#  'Azzougarh',
#  'TJOS',
#  'Ḩasam',
#  'Epps',
#  'Rech.f',
#  'n-ṣ-r',
#  '11-5-1',
#  'Grenville-Wells',
#  'kopovi',
#  'Tingatinga',
#  '1-600',
#  'art-therapy',
#  'oneknife',
#  '23832',
#  'sheep-herder',
#  'assessment/intervention',
#  'بانہال',
#  'Regreen',
#  'AKTU',
#  'AskMD',
#  'Tortuosa',
#  'CREATED',
#  'BentleyForbes',
#  'Cajtlin',
#  '1900-1937',
#  'Sikhae',
#  'Tǔhuà',
#  '37.8',
#  'Kirvin',
#  'Maharajji',
#  '-681',
#  'office/hospital',
#  'enneahedron',
#  'ServON',
#  'Dattajivo',
#  'single-asset',
#  'Sulkow',
#  'Tearce-97',
#  'HHRO',
#  'Beta-galactosidases',
#  'WFRV-TV',
#  'ericjhellergallery.com',
#  'Veissière',
#  'Celtiagh',
#  'Junction-Rotherwood',
#  'ɐxˈmadəvʲɪtɕ',
#  '熠熠星光总动员',
#  'NATO-HELICOPTER',
#  'vapour-pressure',
#  'Kopyt',
#  'Karşılaması',
#  'then-6th',
#  'Oldtymers',
#  'Marsilly',
#  'EMPC',
#  'Silfvast',
#  'cavanas',
#  'singer/composer/producer',
#  'Cloan',
#  'Demofest',
#  'UEK',
#  'Kundrathur',
#  'Profitt',
#  'Tharavadinte',
#  'ouai',
#  'D-Monroe',
#  '27,269',
#  'Zohara',
#  'Neo-Luddite',
#  'Fluid-jet',
#  'anagestone',
#  'Chakodi',
#  'Khotov',
#  'Tiflis-Alexandropol',
#  'Czechosłowacji',
#  'sealers',
#  'KOTOR',
#  'verais',
#  '12-m',
#  'ˈʁoːtɐmʊnt',
#  'boo-boys',
#  'Slovinska',
#  '1559-1623',
#  'Decapitones',
#  'iDataCool',
#  'Atzilus',
#  'Vrapice',
#  'Hah-kah',
#  'Jean',
#  'WHFX',
#  '2,285,067',
#  'BLSE',
#  'grundlovgivende',
#  'dinitro-2',
#  'Prêt-à-Porter',
#  'Re-LIVE',
#  'Buccahad',
#  'desertae',
#  'Roboré',
#  'Soulwax',
#  'Corfu-island',
#  'Planinić',
#  'roughneck',
#  'Regiments',
#  'Anizan',
#  'Румъния',
#  'Norn-speakers',
#  'За́падно',
#  'Nprth',
#  'Rajbaug',
#  'GMTA',
#  'Abagadasset',
#  'Parkers',
#  'Halehomaha',
#  'Middleweek',
#  '64-88',
#  'OnForce',
#  'مخبز',
#  'Allegorically',
#  'Zahkarov',
#  'Strazvrid',
#  '5,947,213',
#  'Europaeus',
#  'Chornoriky',
#  'Tiegelmann',
#  'mâu',
#  'Cochran',
#  '0739',
#  'earth-integrated',
#  'utilitarianism',
#  'қуу',
#  'A49/B4370',
#  '174818',
#  'Enarg',
#  'suprapellis',
#  'Qaramqũl',
#  'Ulgenes',
#  'constellationof',
#  '河俊任',
#  'Tabscoob',
#  'Pork',
#  'Ia3m',
#  'Bandasuma',
#  'Ratafia',
#  'Imegwu',
#  'Microweiseinae',
#  'Jirnsum',
#  'Fulsztyn',
#  'Solimani',
#  'biscuit-crumb',
#  '0896-3207',
#  'Vielfalt',
#  'Loena',
#  'Diapalpus',
#  '1847-1858',
#  '267.183444',
#  'Jehan.Lyrics',
#  '05580',
#  'TIDEL',
#  'all-clear',
#  'Jafarov',
#  'dogsitters',
#  'whitelockiana',
#  'Mārfi',
#  'Elissery',
#  'Unnilseptium',
#  'Kāpiti',
#  'Saint-Seurin-de-Prats',
#  'Alphonsa',
#  'Barnali',
#  '755-97',
#  '245-252',
#  'Bangkokbiznews',
#  'Mauborget',
#  'Natsuzuki',
#  'Hēnare',
#  'OAO-2',
#  'VCPRD',
#  'Canev',
#  'Botifoll',
#  'Estoniops',
#  'Neomodus',
#  'silphion',
#  'Baruny',
#  '2-205',
#  'Unamerican',
#  'Clonygowan',
#  'Vinício',
#  'Nopca',
#  'Fiakas',
#  'اوگون',
#  'Qandahār-nāma',
#  'Huangpiqiang',
#  'Mzieme',
#  'Zaparoana',
#  'עילית',
#  'Kavelan-e',
#  'Lufus',
#  'Plasmodium',
#  'Fictel',
#  'fifth-class',
#  'Roltdalen',
#  'Chloros',
#  'Reikhi',
#  'Rhabdocoela',
#  'Achingale',
#  'Yerushalayim/Al',
#  'Kiraron',
#  'Dolagovinda',
#  'teen-age',
#  'assassin',
#  'Ellence',
#  'Taschenbergpalais',
#  'Lacue',
#  'PQAs',
#  '1637-I',
#  'nacnac',
#  'WWll',
#  'weissgrundige',
#  'Villicaña',
#  'Z-Gang',
#  'nonfermenters',
#  'UWE-2',
#  'capability-providing',
#  'PANAM',
#  'TRATS',
#  'Мусоргский',
#  'Powell-Reed',
#  'F-300',
#  'Shikadi',
#  'Westarctica',
#  'Π02-theorems',
#  'Morkovsky',
#  'rasande',
#  'Sachs-Osher',
#  'Erasmos',
#  'Tharika',
#  'Linghorn',
#  '2-6-92',
#  'Carlomann',
#  'Celle-les-Bordes',
#  'Kokroman',
#  'Relojero',
#  'D.O.C.',
#  'Muarem',
#  'interthalamic',
#  'XHRHI-FM',
#  'Corendon',
#  'Al-Andalusiya',
#  'Scario',
#  'Chlorides',
#  'philia',
#  'Codementor',
#  'additionally',
#  'Burke',
#  'Gallimore',
#  'three-seeded',
#  '945,299',
#  'GAS-specific',
#  'off-airport',
#  'Κλύσωνυμος',
#  'Eyfi',
#  'SolSuite',
#  'ˈɪŋmar',
#  'Amaryngkëidês',
#  '296,739',
#  'Sunflour',
#  'Kaalazhaga',
#  'ADE',
#  'Annamitta',
#  'Panales',
#  'clusterheads',
#  '0-312-42171-0',
#  'Shafiz',
#  'A972',
#  'Krasovska',
#  'Wekusko',
#  '18627',
#  'YMS-215',
#  'Linnéenne',
#  '84e',
#  'GloboEsporte.com',
#  '10-Shi',
#  'fishrock',
#  '18,876',
#  'motorcycle-fender',
#  "L'Embarras",
#  'Cuchiniș',
#  'Sultartangastöð',
#  '200-second',
#  'scoutfor',
#  'Fief',
#  'W60-only',
#  'Isomma',
#  'nonjurant',
#  'ActUp',
#  'shortbreat-type',
#  'źuga',
#  'Froy',
#  'taIńska',
#  'Kausbekovich',
#  'boulodromes',
#  'Scaglia',
#  'Cydewain',
#  'semicognata',
#  'carpincho',
#  'Zenret',
#  'بهادرئ',
#  'nuclear-blasted',
#  '1110s',
#  'safety-word',
#  'selffinancing',
#  'Grapow',
#  'Chrysolaena',
#  'TNT/TBS',
#  'Dougla',
#  'Souakri',
#  'Атомэнергопром',
#  'divyā́',
#  'Stazak',
#  'Φίλιπποι',
#  'Ghosks',
#  'Noemfoer',
#  'two-generator',
#  '8307',
#  'Clementino',
#  'lonek',
#  'Ajinyaz',
#  'Nebbi',
#  'nɔːrˈθʌmbərlənd',
#  'Rajadamnern',
#  'PHOTOESPAÑA',
#  'intercepting',
#  'Desmoglein-4',
#  'Lethent',
#  'Heegoo',
#  'Zitatenschatz',
#  'man-trailer',
#  'Maestro/Cirrus',
#  'Krystalak',
#  'non-Nauruan',
#  'UNMACC',
#  'Masjid-Al-Aqsa',
#  'protozoan',
#  'WeSET',
#  '1054th',
#  'Byngham',
#  'Richsquare',
#  'Recaido',
#  '10001110101',
#  'Stormwatch',
#  'balkuf',
#  '20,000-square-foot',
#  'SAFMAR',
#  'Sahkanaga',
#  'waterrequested',
#  'MC-101',
#  'wall-run',
#  'Hablitz',
#  'honum',
#  'ŋʷˤa',
#  'Anyer-Labuan',
#  'Argyrokastro',
#  'gray-blue',
#  'Ambrosano',
#  'intrépides',
#  'Tementhes',
#  'Raymondo',
#  'Andonyadis',
#  'Tripps',
#  'Shāl',
#  'Condylidium',
#  'Entrata',
#  'Pookunhikoya',
#  'D31b',
#  'Kővágószőlős',
#  'solbon',
#  'guardian-angel',
#  'Thr11',
#  'Ertzica',
#  'Station-Shromojibi',
#  'seasides',
#  'Sevskoye',
#  'Clowry',
#  'Thukhar',
#  'Ueckermünde',
#  'Nikšićka',
#  'Ton-Pentre',
#  'County-National',
#  'Moneygall',
#  'Rājyāñchā',
#  'Pinders',
#  'seyriganus',
#  'Otaniemen',
#  'tararua',
#  'rs12970134',
#  '1324/5',
#  'X960',
#  'ploughteams',
#  'Paerformace',
#  'non-miraculous',
#  '136.05',
#  'Tolour',
#  'S-VYASA',
#  "Y's",
#  'C12195',
#  'McHappy',
#  'molator',
#  'Salījān',
#  'księżną',
#  'filterless',
#  'комітет',
#  'presoaking',
#  'Megatel',
#  'ܨܠܘܬܐ',
#  'maɪˈæmiːzbərg',
#  'SouthernLINC',
#  'Weinblatt',
#  'dainty-looking',
#  'معاونت',
#  'Sundowe',
#  'previouslye',
#  'SYSOPS',
#  'periwigs',
#  'Irishenco',
#  'al-Qazwini',
#  'Trentepohlia',
#  'Vinassan',
#  'Rhypotoses',
#  'collectivization',
#  'RHAM/1',
#  'NAAT-II',
#  'Heeriye',
#  'N.tabacum',
#  'Choza',
#  'Alfāūūt',
#  'pale-flecked',
#  'Riidamäe',
#  'Тодорчев',
#  '7919601',
#  'ماهنامه',
#  'Surgeonfishes',
#  'DBs',
#  'Shemer',
#  'sucrose-glucan',
#  'Baciocco',
#  '41stGolden',
#  'Rochebaudin',
#  'EVENING',
#  'antikhrist',
#  'Arattana',
#  '2018m',
#  'Vaudreuille',
#  '16Z',
#  'Isoetopsida',
#  '中国武术',
#  'Kollerschlag',
#  'Ex-Stratovarius',
#  'zero-issue',
#  'HASCO',
#  '6,885',
#  'GOKUL.A',
#  'Jevišovice',
#  'Sakihisa',
#  'gelatinase-associated',
#  '1921-1953',
#  'Paramorbia',
#  'Maraviev',
#  'silver-plating',
#  'cyanetron',
#  'MuLab',
#  'Amoenus',
#  'Bathiste',
#  'Венков',
#  'stara-kośće1l',
#  'Liulf',
#  'Kvitfjell',
#  '58P/Jackson-Neujmin',
#  'Natronobacterium',
#  'ctenoneurus',
#  'Iaccaci',
#  'CCOA',
#  'McPark',
#  'E-CDs',
#  'Methofuran',
#  'Barduń',
#  'Prugovac',
#  'Bangaeira',
#  'Chahardangi',
#  'RONIN',
#  '24-1Lost',
#  '28,665',
#  '9312',
#  'logothetes',
#  'Maieco',
#  'Auctum',
#  'post-serialist',
#  'svestvi',
#  'cuahuitl',
#  'bullae',
#  'Starkbaum',
#  'Takurō',
#  'Kaaraku',
#  'ninithi',
#  'droids',
#  'banaˈnaw',
#  '周書',
#  'Hakuoro',
#  'Qalātū',
#  'designatum',
#  'Maduravoyal',
#  'Gallenburg',
#  'scarification',
#  'Jingoism',
#  'Charuvi',
#  'end-products',
#  '2,115,234',
#  'Railroading',
#  'ArtDaily',
#  'DMMMSU-SLUC',
#  'Drakšl',
#  'Matsdotter',
#  'MyEnvironment',
#  'ski-yoo',
#  'Zeitgeist',
#  ...]

# %%
from tqdm import tqdm
from utils_db import dict_load_json
path_claims = '/mnt/01_thesis/01_code/ESIM/tmp2/document_retrieval'
nr_claims = 1#19998
for claim_nr in tqdm(range(nr_claims)):
    path_claim = os.path.join(path_claims, str(claim_nr) + '.json')
    claim_dict = dict_load_json(path_claim)

    for doc_nr in claim_dict['document_retrieval']:
        line_list = wiki_database.get_lines_from_id(doc_nr)
        nr_lines = len(line_list)
        for line_nr in claim_dict['document_retrieval'][doc_nr]:
            print(claim_dict['document_retrieval'][doc_nr][line_nr])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,
# 12561.json  15132.json	17704.json  2278.json	485.json   7420.json  9993.json
# 12562.json  15133.json	17705.json  2279.json	4850.json  7421.json  9994.json
# 12563.json  15134.json	17706.json  228.json	4851.json  7422.json  9995.json
# 12564.json  15135.json	17707.json  2280.json	4852.json  7423.json  9996.json
# 12565.json  15136.json	17708.json  2281.json	4853.json  7424.json  9997.json
# 12566.json  15137.json	17709.json  2282.json	4854.json  7425.json  9998.json
# 12567.json  15138.json	1771.json   2283.json	4855.json  7426.json  9999.json
# 12568.json  15139.json	17710.json  2284.json	4856.json  7427.json

# %% [markdown]
# # To do:

# %% [markdown]
#     - A: Create Wikidatabase for document retrieval method
#     - B: Create Sentence selection for sentence retrieval method
#     - C: Predict label for claim
#     - D: Score

# %%
from utils_db import get_file_name_from_variable_list

embeddings_settings_sentence_retrieval_list = []
embeddings_settings_label_prediction_list = []

path_base_dir = 'tmp'
path_document_retrieval_dir = os.path.join(path_base_dir, get_file_name_from_variable_list('document_retrieval'))
path_sentence_retrieval_dir = os.path.join(path_base_dir, 'sentence_retrieval')
path_label_prediction_dir = os.path.join(path_base_dir, 'label_prediction')

for embeddings_setting in embeddings_settings_sentence_retrieval_list:
    path_sentence_retrieval_dir = get_file_name_from_variable_list(path_sentence_retrieval_dir, embeddings_setting)

for embeddings_setting in embeddings_settings_label_prediction_list:
    path_label_prediction_dir = get_file_name_from_variable_list(path_label_prediction_dir, embeddings_setting)

path_settings_dict = os.path.join(path_base_dir)

# %%
tmp = {}
tmp['hoi'] = []
tmp['hoi'].append([1,2])
tmp['hoi'].append([3,4])
tmp
# Out:
# {'hoi': [[1, 2], [3, 4]]}

# %%
import torch
from esim.model import ESIM
import pickle

word_dict = pickle.load( open( path_word_dict, "rb" ) )

# stage 2
path_stage_2_model = '/mnt/01_thesis/01_code/ESIM/data/checkpoints/FEVER_stage_2_pos_oov/esim_2.pth.tar'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

checkpoint = torch.load(path_stage_2_model)

# Retrieving model parameters from checkpoint.
vocab_size = checkpoint["model"]["_word_embedding.weight"].size(0)
embedding_dim = checkpoint["model"]['_word_embedding.weight'].size(1)
hidden_size = checkpoint["model"]["_projection.0.weight"].size(0)
num_classes = checkpoint["model"]["_classification.4.weight"].size(0)

model = ESIM(vocab_size,
             embedding_dim,
             hidden_size,
             num_classes=num_classes,
             use_pos_tag_flag=1,
             use_oov_flag=1,
             device=device).to(device)

model.load_state_dict(checkpoint["model"])

model.eval()

# %%
import six

def check_predicted_evidence_format(instance):
    if 'predicted_evidence' in instance.keys() and len(instance['predicted_evidence']):
        assert all(isinstance(prediction, list)
                   for prediction in instance["predicted_evidence"]), \
            "Predicted evidence must be a list of (page,line) lists"

        assert all(len(prediction) == 2
                   for prediction in instance["predicted_evidence"]), \
            "Predicted evidence must be a list of (page,line) lists"

        assert all(isinstance(prediction[0], six.string_types)
                    for prediction in instance["predicted_evidence"]), \
            "Predicted evidence must be a list of (page<string>,line<int>) lists"

        assert all(isinstance(prediction[1], int)
                   for prediction in instance["predicted_evidence"]), \
            "Predicted evidence must be a list of (page<string>,line<int>) lists"


def is_correct_label(instance):
    return instance["label"].upper() == instance["predicted_label"].upper()


def is_strictly_correct(instance, max_evidence=None):
    #Strict evidence matching is only for NEI class
    check_predicted_evidence_format(instance)

    if instance["label"].upper() != "NOT ENOUGH INFO" and is_correct_label(instance):
        assert 'predicted_evidence' in instance, "Predicted evidence must be provided for strict scoring"

        if max_evidence is None:
            max_evidence = len(instance["predicted_evidence"])


        for evience_group in instance["evidence"]:
            #Filter out the annotation ids. We just want the evidence page and line number
            actual_sentences = [[e[2], e[3]] for e in evience_group]
            #Only return true if an entire group of actual sentences is in the predicted sentences
            if all([actual_sent in instance["predicted_evidence"][:max_evidence] for actual_sent in actual_sentences]):
                return True

    #If the class is NEI, we don't score the evidence retrieval component
    elif instance["label"].upper() == "NOT ENOUGH INFO" and is_correct_label(instance):
        return True

    return False


def evidence_macro_precision(instance, max_evidence=None):
    this_precision = 0.0
    this_precision_hits = 0.0

    if instance["label"].upper() != "NOT ENOUGH INFO":
        all_evi = [[e[2], e[3]] for eg in instance["evidence"] for e in eg if e[3] is not None]

        predicted_evidence = instance["predicted_evidence"] if max_evidence is None else \
                                                                        instance["predicted_evidence"][:max_evidence]

        for prediction in predicted_evidence:
            if prediction in all_evi:
                this_precision += 1.0
            this_precision_hits += 1.0

        return (this_precision / this_precision_hits) if this_precision_hits > 0 else 1.0, 1.0

    return 0.0, 0.0

def evidence_macro_recall(instance, max_evidence=None):
    # We only want to score F1/Precision/Recall of recalled evidence for NEI claims
    if instance["label"].upper() != "NOT ENOUGH INFO":
        # If there's no evidence to predict, return 1
        if len(instance["evidence"]) == 0 or all([len(eg) == 0 for eg in instance]):
           return 1.0, 1.0

        predicted_evidence = instance["predicted_evidence"] if max_evidence is None else \
                                                                        instance["predicted_evidence"][:max_evidence]

        for evidence_group in instance["evidence"]:
            evidence = [[e[2], e[3]] for e in evidence_group]
            if all([item in predicted_evidence for item in evidence]):
                # We only want to score complete groups of evidence. Incomplete groups are worthless.
                return 1.0, 1.0
        return 0.0, 1.0
    return 0.0, 0.0


# Micro is not used. This code is just included to demostrate our model of macro/micro
def evidence_micro_precision(instance):
    this_precision = 0
    this_precision_hits = 0

    # We only want to score Macro F1/Precision/Recall of recalled evidence for NEI claims
    if instance["label"].upper() != "NOT ENOUGH INFO":
        all_evi = [[e[2], e[3]] for eg in instance["evidence"] for e in eg if e[3] is not None]

        for prediction in instance["predicted_evidence"]:
            if prediction in all_evi:
                this_precision += 1.0
            this_precision_hits += 1.0

    return this_precision, this_precision_hits


def fever_score(predictions,actual=None, max_evidence=5):
    correct = 0
    strict = 0

    macro_precision = 0
    macro_precision_hits = 0

    macro_recall = 0
    macro_recall_hits = 0

    for idx,instance in enumerate(predictions):
        assert 'predicted_evidence' in instance.keys(), 'evidence must be provided for the prediction'

        #If it's a blind test set, we need to copy in the values from the actual data
        if 'evidence' not in instance or 'label' not in instance:
            assert actual is not None, 'in blind evaluation mode, actual data must be provided'
            assert len(actual) == len(predictions), 'actual data and predicted data length must match'
            assert 'evidence' in actual[idx].keys(), 'evidence must be provided for the actual evidence'
            instance['evidence'] = actual[idx]['evidence']
            instance['label'] = actual[idx]['label']

        assert 'evidence' in instance.keys(), 'gold evidence must be provided'

        if is_correct_label(instance):
            correct += 1.0

            if is_strictly_correct(instance, max_evidence):
                strict+=1.0

        macro_prec = evidence_macro_precision(instance, max_evidence)
        macro_precision += macro_prec[0]
        macro_precision_hits += macro_prec[1]

        macro_rec = evidence_macro_recall(instance, max_evidence)
        macro_recall += macro_rec[0]
        macro_recall_hits += macro_rec[1]

    total = len(predictions)

    strict_score = strict / total
    acc_score = correct / total

    pr = (macro_precision / macro_precision_hits) if macro_precision_hits > 0 else 1.0
    rec = (macro_recall / macro_recall_hits) if macro_recall_hits > 0 else 0.0

    f1 = 2.0 * pr * rec / (pr + rec)

    return strict_score, acc_score, pr, rec, f1

# %%
from utils_db import dict_load_json, dict_save_json
from utils_db import get_file_name_from_variable_list
from tqdm import tqdm

class EntireSystem():
    
    def __init__(self, wiki_database, nlp, path_stage_2_model, path_stage_3_model,
                 path_dir_doc_selected, method_tokenization, path_base_dir,
                 path_word_dict_stage_2, path_word_dict_stage_3,
                 embeddings_settings_sentence_retrieval_list = [],
                 embeddings_settings_label_prediction_list = []):
        # === process inputs === #
        self.path_stage_2_model = path_stage_2_model
        self.path_stage_3_model = path_stage_3_model
        self.nlp = nlp
        self.path_dir_doc_selected = path_dir_doc_selected
        self.method_tokenization = method_tokenization
        self.path_base_dir = path_base_dir
        self.path_word_dict_stage_2 = path_word_dict_stage_2
        self.path_word_dict_stage_3 = path_word_dict_stage_3
        self.embeddings_settings_sentence_retrieval_list = embeddings_settings_sentence_retrieval_list
        self.embeddings_settings_label_prediction_list = embeddings_settings_label_prediction_list
        
        # === paths === #
        self.path_document_retrieval_dir = os.path.join(path_base_dir, get_file_name_from_variable_list(['document_retrieval']))
        self.path_sentence_retrieval_dir = os.path.join(path_base_dir, 'sentence_retrieval')
        self.path_label_prediction_dir = os.path.join(path_base_dir, 'label_prediction')
        
        for embeddings_setting in embeddings_settings_sentence_retrieval_list:
            self.path_sentence_retrieval_dir = get_file_name_from_variable_list([self.path_sentence_retrieval_dir, embeddings_setting])

        for embeddings_setting in embeddings_settings_label_prediction_list:
            self.path_label_prediction_dir = get_file_name_from_variable_list([self.path_label_prediction_dir, embeddings_setting])
        
        if not os.path.isdir(self.path_base_dir):
            os.makedirs(self.path_base_dir)
                       
        self.path_settings = os.path.join(self.path_base_dir, 'settings.json')
        
        if os.path.isfile(self.path_settings):
            self.settings = dict_load_json(self.path_settings)
        else:
            self.settings = {}
        
        if 'nr_claims' not in self.settings:
            self.settings['nr_claims'] = self.nr_files_in_dir(self.path_dir_doc_selected)
            self.save_settings()
            
        self.nr_claims = self.settings['nr_claims']
#         self.nr_claims = 100
        print('nr claims:', self.nr_claims)
        
        # === process === #
        self.tag_2_id_dict = get_tag_2_id_dict_unigrams()
    
        if not os.path.isdir(self.path_document_retrieval_dir):
            os.makedirs(self.path_document_retrieval_dir)
            self.document_retrieval()
        
#         if not os.path.isdir(self.path_sentence_retrieval_dir):
#             os.makedirs(self.path_sentence_retrieval_dir)
#             self.sentence_retrieval()
            
#         if not os.path.isdir(self.path_label_prediction_dir):
#             os.makedirs(self.path_label_prediction_dir)
#             self.label_prediction()
            
#         self.compute_score()
        
    def compute_score(self):
        # STAGE 2
        # F1
        # PRECISION
        # RECALL
        
        # STAGE 3
        # FEVER
        
        list_claims = []
        for claim_nr in tqdm(range(self.nr_claims)):
            path_claim = os.path.join(self.path_label_prediction_dir, str(claim_nr) + '.json')
            claim_dict = dict_load_json(path_claim)
            list_claims.append(claim_dict)
        
        strict_score, acc_score, pr, rec, f1 = fever_score(predictions=list_claims, actual=None, max_evidence=5)
        
        self.setings['score_metrics'] = {}
        self.settings['score_metrics']['strict_score'] = strict_score
        self.settings['score_metrics']['acc_score'] = acc_score
        self.settings['score_metrics']['pr'] = pr
        self.settings['score_metrics']['rec'] = rec
        self.settings['score_metrics']['f1'] = f1
        
        self.save_settings()
        
        print(strict_score, acc_score, pr, rec, f1)
        
    
    def label_prediction(self):
        print('- label prediction: initialise')
        word_dict = pickle.load( open( self.path_word_dict_stage_3, "rb" ) )
        
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

        checkpoint = torch.load(self.path_stage_3_model)

        vocab_size = checkpoint["model"]["_word_embedding.weight"].size(0)
        embedding_dim = checkpoint["model"]['_word_embedding.weight'].size(1)
        hidden_size = checkpoint["model"]["_projection.0.weight"].size(0)
        num_classes = checkpoint["model"]["_classification.4.weight"].size(0)
        
        use_oov_flag=0
        if 'oov' in self.embeddings_settings_label_prediction_list:
            use_oov_flag=1
            
        use_pos_tag_flag=0
        if 'pos' in self.embeddings_settings_label_prediction_list:
            use_pos_tag_flag=1
            
        model = ESIM(vocab_size,
                     embedding_dim,
                     hidden_size,
                     num_classes=num_classes,
                     use_pos_tag_flag=use_pos_tag_flag,
                     use_oov_flag=use_oov_flag,
                     device=device).to(device)

        model.load_state_dict(checkpoint["model"])

        model.eval()
        
        print('- label prediction: iterate through claims')
        for claim_nr in tqdm(range(self.nr_claims)):
            path_claim = os.path.join(self.path_sentence_retrieval_dir, str(claim_nr) + '.json')
            claim_dict = dict_load_json(path_claim)
            
            prob_list  = []
            prob_list_supported = []
            prob_list_refuted = []
            for i in range(len(claim_dict['sentence_retrieval']['doc_nr_list'])):
                doc_nr = claim_dict['sentence_retrieval']['doc_nr_list'][i]
                line_nr = claim_dict['sentence_retrieval']['line_nr_list'][i]
                prob = compute_prob_stage_3(model, claim_dict, doc_nr, line_nr)
                prob_list.append(prob)
                prob_list_supported.append(prob[2])
                prob_list_refuted.append(prob[1])
                
            if max(prob_list_supported) > 0.5:
                claim_dict['predicted_label'] = 'SUPPORTS'
            elif max(prob_list_refuted) > 0.5:
                claim_dict['predicted_label'] = 'REFUTES'
            else:
                claim_dict['predicted_label'] = 'NOT ENOUGH INFO'
            
            path_save = os.path.join(self.path_label_prediction_dir, str(claim_nr) + '.json')
            self.save_dict(claim_dict, path_save)
                
    def sentence_retrieval(self):
        print('- sentence retrieval: initialise')
        word_dict = pickle.load( open( self.path_word_dict_stage_2, "rb" ) )
        
        device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

        checkpoint = torch.load(self.path_stage_2_model)

        vocab_size = checkpoint["model"]["_word_embedding.weight"].size(0)
        embedding_dim = checkpoint["model"]['_word_embedding.weight'].size(1)
        hidden_size = checkpoint["model"]["_projection.0.weight"].size(0)
        num_classes = checkpoint["model"]["_classification.4.weight"].size(0)
        
        use_oov_flag=0
        if 'oov' in self.embeddings_settings_sentence_retrieval_list:
            use_oov_flag=1
            
        use_pos_tag_flag=0
        if 'pos' in self.embeddings_settings_sentence_retrieval_list:
            use_pos_tag_flag=1
            
        model = ESIM(vocab_size,
                     embedding_dim,
                     hidden_size,
                     num_classes=num_classes,
                     use_pos_tag_flag=use_pos_tag_flag,
                     use_oov_flag=use_oov_flag,
                     device=device).to(device)

        model.load_state_dict(checkpoint["model"])

        model.eval()
        
        print('- sentence retrieval: iterate through claims')
        for claim_nr in tqdm(range(self.nr_claims)):
            path_claim = os.path.join(self.path_document_retrieval_dir, str(claim_nr) + '.json')
            claim_dict = dict_load_json(path_claim)
            
            list_prob = []
            list_doc_nr = []
            list_line_nr = []
        
            for doc_nr in claim_dict['document_retrieval']:
                for line_nr in claim_dict['document_retrieval'][doc_nr]:
                    if 'sentence_retrieval' not in claim_dict:
                        claim_dict['sentence_retrieval'] = {}
                    if doc_nr not in claim_dict['sentence_retrieval']:
                        claim_dict['sentence_retrieval'][doc_nr] = {}
                    if line_nr not in claim_dict['sentence_retrieval'][doc_nr]:
                        claim_dict['sentence_retrieval'][doc_nr][line_nr] = {}
                    
                    prob = compute_prob_stage_2(model, claim_dict, doc_nr, line_nr)
                    claim_dict['sentence_retrieval'][doc_nr][line_nr]['prob'] = prob
                    
                    list_doc_nr.append(doc_nr)
                    list_line_nr.append(line_nr)
                    list_prob.append(prob)
                    
            sorted_list_doc_nr = sort_list(list_doc_nr, list_prob)[-5:]
            sorted_list_line_nr = sort_list(list_line_nr, list_prob)[-5:]
            sorted_list_prob = sort_list(list_prob, list_prob)[-5:]
            claim_dict['sentence_retrieval']['doc_nr_list'] = sorted_list_doc_nr  
            claim_dict['sentence_retrieval']['line_nr_list'] = sorted_list_line_nr  
            claim_dict['sentence_retrieval']['prob_list'] = sorted_list_prob 
            
            claim_dict['predicted_evidence'] = []
            for i in range(len(sorted_list_doc_nr)):
                doc_nr = sorted_list_doc_nr[i]
                title = wiki_database.get_title_from_id(int(doc_nr))
                line_nr = int(sorted_list_line_nr[i])
                claim_dict['predicted_evidence'].append([title, line_nr])                                   
            
            path_save = os.path.join(self.path_sentence_retrieval_dir, str(claim_nr) + '.json')
            self.save_dict(claim_dict, path_save)
                    
        
    def document_retrieval(self):
#         claim_nr = 12
#         line_nr = 0
#         nr_in_doc_selected_list = 0
        word_dict = pickle.load( open( self.path_word_dict_stage_2, "rb" ) )
    
        for claim_nr in tqdm(range(self.nr_claims)):
            path_claim = os.path.join(self.path_dir_doc_selected, str(claim_nr) + '.json')
            claim_dict = dict_load_json(path_claim)
            claim = Claim(claim_dict)
            claim_text = claim.claim
            # === process word tags and word list === #
            tag_list_claim, word_list_claim = get_word_tag_list_from_text(text_str = claim_text, 
                                                                          nlp = nlp, 
                                                                          method_tokenization_str = method_tokenization)

            for doc_nr in claim_dict['docs_selected']:
                line_list = wiki_database.get_lines_from_id(doc_nr)
                nr_lines = len(line_list)
                for line_nr in range(nr_lines):
                    line_text = line_list[line_nr]
                    
                    # === process word tags and word list === #
                    tag_list_line, word_list_line = get_word_tag_list_from_text(text_str = line_text, 
                                                                                nlp = nlp, 
                                                                                method_tokenization_str = method_tokenization)

                    claim_dict['document_retrieval'] = {}
                    if str(doc_nr) not in claim_dict['document_retrieval']:
                        claim_dict['document_retrieval'][str(doc_nr)] = {}

                    if str(line_nr) not in claim_dict['document_retrieval'][str(doc_nr)]:
                        claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)] = {}

                    if 'claim' not in claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]:
                        claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['claim'] = {}

                    if 'document' not in claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]:
                        claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['document'] = {}

                    claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['claim']['tag_list'] = [17] + tag_str_2_id_list(
                        tag_list_claim, tag_2_id_dict) + [17]
                    claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['claim']['word_list'] = word_list_2_id_list(
                        ["_BOS_"] + word_list_claim + ["_EOS_"], word_dict)
                    claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['document']['tag_list'] = [17] + tag_str_2_id_list(
                        tag_list_line, tag_2_id_dict) + [17]
                    claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['document']['word_list'] = word_list_2_id_list(
                        ["_BOS_"] + word_list_line + ["_EOS_"], word_dict)

                    ids_document, ids_claim = hypothesis_evidence_2_index(hypothesis = word_list_line,
                                               premise = word_list_claim,
                                               randomise_flag = False)

                    claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['claim']['exact_match_list'] = [0] + ids_claim + [1]
                    claim_dict['document_retrieval'][str(doc_nr)][str(line_nr)]['document']['exact_match_list'] = [0] + ids_document + [1]
            
            path_save = os.path.join(self.path_document_retrieval_dir, str(claim_nr) + '.json')
            self.save_dict(claim_dict, path_save)
            
    def save_settings(self):
        dict_save_json(self.settings, self.path_settings)
    
    def save_dict(self, input_dict, path):
        dict_save_json(input_dict, path)
        
    def load_dict(self, path):
        return dict_load_json(path)
    
    def nr_files_in_dir(self, path_dir):
        list_files = os.listdir(path_dir) # dir is your directory path
        number_files = len(list_files)
        return number_files

# %%
! rm -r tmp

# %%
path_dir_doc_selected = '/mnt/01_thesis/01_code/fever/_04_results/vocab_title_1_t/thr_0.01_/ex_term_frequency_inverse_document_frequency_title/results_experiment_dev_tf_idf_normalise_20/claims_dev'
method_tokenization = 'tokenize_text_pos'
path_base_dir = 'tmp2'
path_word_dict_stage_2 = os.path.join('/mnt/01_thesis/01_code/ESIM/data/preprocessed/FEVER_stage_2', 'worddict.pkl')
path_word_dict_stage_3 = os.path.join('/mnt/01_thesis/01_code/ESIM/data/preprocessed/FEVER_stage_3', 'worddict.pkl')

path_stage_2_model = '/mnt/01_thesis/01_code/ESIM/data/checkpoints/FEVER_stage_2_pos_oov/best.pth.tar'
path_stage_3_model = '/mnt/01_thesis/01_code/ESIM/data/checkpoints/FEVER_stage_3_pos_oov/best.pth.tar'

embeddings_settings_sentence_retrieval_list = ['pos', 'oov']
embeddings_settings_label_prediction_list = ['pos', 'oov']

entire_system = EntireSystem(wiki_database, nlp, path_stage_2_model, path_stage_3_model, 
                 path_dir_doc_selected, method_tokenization, path_base_dir,
                 path_word_dict_stage_2, path_word_dict_stage_3,
                 embeddings_settings_sentence_retrieval_list = embeddings_settings_sentence_retrieval_list,
                 embeddings_settings_label_prediction_list = embeddings_settings_label_prediction_list)
# Out:
#   0%|          | 0/19999 [00:00<?, ?it/s]
# nr claims: 19999
#   0%|          | 1/19999 [00:00<2:40:13,  2.08it/s]
#
#
#
#   0%|          | 2/19999 [00:00<2:20:29,  2.37it/s]
#
#
#
#   0%|          | 3/19999 [00:01<2:07:56,  2.60it/s]
#
#
#
#   0%|          | 4/19999 [00:01<2:13:16,  2.50it/s]
#
#
#
#   0%|          | 5/19999 [00:01<2:15:10,  2.47it/s]
#
#
#
#   0%|          | 6/19999 [00:02<2:08:12,  2.60it/s]
#
#
#
#   0%|          | 7/19999 [00:02<2:01:05,  2.75it/s]
#
#
#
#   0%|          | 8/19999 [00:02<1:47:11,  3.11it/s]
#
#
#
#   0%|          | 9/19999 [00:03<1:49:17,  3.05it/s]
#
#
#
#   0%|          | 10/19999 [00:03<1:45:09,  3.17it/s]
#
#
#
#   0%|          | 11/19999 [00:03<1:35:22,  3.49it/s]
#
#
#
#   0%|          | 12/19999 [00:03<1:27:39,  3.80it/s]
#
#
#
#   0%|          | 13/19999 [00:04<1:33:15,  3.57it/s]
#
#
#
#   0%|          | 14/19999 [00:04<1:34:50,  3.51it/s]
#
#
#
#   0%|          | 15/19999 [00:04<1:40:57,  3.30it/s]
#
#
#
#   0%|          | 16/19999 [00:05<1:49:31,  3.04it/s]
#
#
#
#   0%|          | 17/19999 [00:05<1:51:52,  2.98it/s]
#
#
#
#   0%|          | 18/19999 [00:06<2:07:19,  2.62it/s]
#
#
#
#   0%|          | 19/19999 [00:06<2:27:53,  2.25it/s]
#
#
#
#   0%|          | 20/19999 [00:06<2:08:19,  2.59it/s]
#
#
#
#   0%|          | 21/19999 [00:07<2:09:00,  2.58it/s]
#
#
#
#   0%|          | 22/19999 [00:07<2:26:41,  2.27it/s]
#
#
#
#   0%|          | 23/19999 [00:08<2:08:29,  2.59it/s]
#
#
#
#   0%|          | 24/19999 [00:08<2:01:50,  2.73it/s]
#
#
#
#   0%|          | 25/19999 [00:08<2:00:43,  2.76it/s]
#
#
#
#   0%|          | 26/19999 [00:09<1:55:47,  2.87it/s]
#
#
#
#   0%|          | 27/19999 [00:09<1:41:56,  3.27it/s]
#
#
#
#   0%|          | 28/19999 [00:09<1:49:19,  3.04it/s]
#
#
#
#   0%|          | 29/19999 [00:10<1:51:13,  2.99it/s]
#
#
#
#   0%|          | 30/19999 [00:10<1:41:56,  3.26it/s]
#
#
#
#   0%|          | 31/19999 [00:10<1:49:39,  3.03it/s]
#
#
#
#
#
#   4%|▍         | 752/19999 [04:15<1:58:15,  2.71it/s]
#
#
#
#   4%|▍         | 753/19999 [04:15<1:48:46,  2.95it/s]
#
#
#
#   4%|▍         | 754/19999 [04:16<1:46:39,  3.01it/s]
#
#
#
#   4%|▍         | 755/19999 [04:16<2:02:38,  2.62it/s]
#
#
#
#   4%|▍         | 756/19999 [04:16<2:03:31,  2.60it/s]
#
#
#
#   4%|▍         | 757/19999 [04:17<1:55:30,  2.78it/s]
#
#
#
#   4%|▍         | 758/19999 [04:17<1:43:15,  3.11it/s]
#
#
#
#   4%|▍         | 759/19999 [04:17<1:47:26,  2.98it/s]
#
#
#
#   4%|▍         | 760/19999 [04:18<2:03:06,  2.60it/s]
#
#
#
#   4%|▍         | 761/19999 [04:18<1:52:09,  2.86it/s]
#
#
#
#   4%|▍         | 762/19999 [04:19<2:01:10,  2.65it/s]
#
#
#
#   4%|▍         | 763/19999 [04:19<1:58:03,  2.72it/s]
#
#
#
#   4%|▍         | 764/19999 [04:19<2:07:35,  2.51it/s]
#
#
#
#   4%|▍         | 765/19999 [04:20<1:53:39,  2.82it/s]
#
#
#
#   4%|▍         | 766/19999 [04:20<1:57:18,  2.73it/s]
#
#
#
#   4%|▍         | 767/19999 [04:20<1:40:23,  3.19it/s]
#
#
#
#   4%|▍         | 768/19999 [04:21<1:42:39,  3.12it/s]
#
#
#
#   4%|▍         | 769/19999 [04:21<1:36:28,  3.32it/s]
#
#
#
#   4%|▍         | 770/19999 [04:21<1:37:15,  3.30it/s]
#
#
#
#   4%|▍         | 771/19999 [04:22<1:51:15,  2.88it/s]
#
#
#
#   4%|▍         | 772/19999 [04:22<1:50:27,  2.90it/s]
#
#
#
#   4%|▍         | 773/19999 [04:22<1:47:54,  2.97it/s]
#
#
#
#   4%|▍         | 774/19999 [04:22<1:39:02,  3.24it/s]
#
#
#
#   4%|▍         | 775/19999 [04:23<1:38:05,  3.27it/s]
#
#
#
#   4%|▍         | 776/19999 [04:23<1:50:10,  2.91it/s]
#
#
#
#   4%|▍         | 777/19999 [04:24<1:52:39,  2.84it/s]
#
#
#
#   4%|▍         | 778/19999 [04:24<1:50:19,  2.90it/s]
#
#
#
#   4%|▍         | 779/19999 [04:24<1:45:34,  3.03it/s]
#
#
#
#   4%|▍         | 780/19999 [04:25<1:54:01,  2.81it/s]
#
#
#
#   4%|▍         | 781/19999 [04:25<2:44:28,  1.95it/s]
#
#
#
#   4%|▍         | 782/19999 [04:26<2:40:49,  1.99it/s]
#
#
#
#   4%|▍         | 783/19999 [04:26<2:19:57,  2.29it/s]
#
#
#
#   4%|▍         | 784/19999 [04:27<2:12:15,  2.42it/s]
#
#
#
#   4%|▍         | 785/19999 [04:27<2:07:42,  2.51it/s]
#
#
#
#   4%|▍         | 786/19999 [04:27<2:00:32,  2.66it/s]
#
#
#
#   4%|▍         | 787/19999 [04:28<1:57:28,  2.73it/s]
#
#
#
#   4%|▍         | 788/19999 [04:28<2:06:02,  2.54it/s]
#
#
#
#   4%|▍         | 789/19999 [04:28<1:50:52,  2.89it/s]
#
#
#
#   4%|▍         | 790/19999 [04:29<1:51:19,  2.88it/s]
#
#
#
#   4%|▍         | 791/19999 [04:29<1:58:25,  2.70it/s]
#
#
#
#   4%|▍         | 792/19999 [04:29<1:49:20,  2.93it/s]
#
#
#
#   4%|▍         | 793/19999 [04:29<1:29:29,  3.58it/s]
#
#
#
#   4%|▍         | 794/19999 [04:30<1:31:09,  3.51it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-171-5f6e9617dad9> in <module>
#      15                  path_word_dict_stage_2, path_word_dict_stage_3,
#      16                  embeddings_settings_sentence_retrieval_list = embeddings_settings_sentence_retrieval_list,
# ---> 17                  embeddings_settings_label_prediction_list = embeddings_settings_label_prediction_list)
#
# <ipython-input-170-dfe5f4b57989> in __init__(self, wiki_database, nlp, path_stage_2_model, path_stage_3_model, path_dir_doc_selected, method_tokenization, path_base_dir, path_word_dict_stage_2, path_word_dict_stage_3, embeddings_settings_sentence_retrieval_list, embeddings_settings_label_prediction_list)
#      56         if not os.path.isdir(self.path_document_retrieval_dir):
#      57             os.makedirs(self.path_document_retrieval_dir)
# ---> 58             self.document_retrieval()
#      59
#      60 #         if not os.path.isdir(self.path_sentence_retrieval_dir):
#
# <ipython-input-170-dfe5f4b57989> in document_retrieval(self)
#     247                     tag_list_line, word_list_line = get_word_tag_list_from_text(text_str = line_text,
#     248                                                                                 nlp = nlp,
# --> 249                                                                                 method_tokenization_str = method_tokenization)
#     250
#     251                     claim_dict['document_retrieval'] = {}
#
# /mnt/01_thesis/01_code/fever/_10_scripts/_10_document_retrieval/claim_database_stage_2_3.py in get_word_tag_list_from_text(text_str, nlp, method_tokenization_str)
#     746
#     747 def get_word_tag_list_from_text(text_str, nlp, method_tokenization_str):
# --> 748     doc = nlp(text_str)
#     749     text = Text(doc)
#     750     delimiter = text.delimiter_position_tag
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     400             if not hasattr(proc, "__call__"):
#     401                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 402             doc = proc(doc, **component_cfg.get(name, {}))
#     403             if doc is None:
#     404                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/api.py in predict(seqs_in)
#     308     def predict(seqs_in):
#     309         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 310         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     311         return layer.ops.unflatten(X, lengths, pad=pad)
#     312
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/resnet.py in predict(self, X)
#      12
#      13     def predict(self, X):
# ---> 14         Y = self._layers[0](X)
#      15         if isinstance(X, list) or isinstance(X, tuple):
#      16             return [X[i] + Y[i] for i in range(len(X))]
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/layernorm.py in predict(self, X)
#      50     def predict(self, X):
#      51         if self.child is not None:
# ---> 52             X = self.child.predict(X)
#      53         N, mu, var = _get_moments(self.ops, X)
#      54         Xh = _forward(self.ops, X, mu, var)
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/_classes/maxout.py in predict(self, X__BI)
#      63
#      64     def predict(self, X__BI):
# ---> 65         W = self.W.reshape((self.nO * self.nP, self.nI))
#      66         X__BOP = self.ops.gemm(X__BI, W, trans2=True)
#      67         X__BOP += self.b.reshape((self.nO * self.nP,))
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/describe.py in __get__(self, obj, type)
#      37         key = (obj.id, self.name)
#      38         if key in obj._mem:
# ---> 39             return obj._mem[key]
#      40         else:
#      41             shape = self.get_shape(obj)
#
# ~/02_environment/01_general_env/lib/python3.6/site-packages/thinc/neural/mem.py in __getitem__(self, name)
#      29         return name in self._offsets
#      30
# ---> 31     def __getitem__(self, name):
#      32         offset, col, shape = self._offsets[name]
#      33         size = self._sizes[name]
#
# KeyboardInterrupt:

# %%
def sort_list(list1, list2): 
    zipped_pairs = zip(list2, list1) 
    z = [x for _, x in sorted(zipped_pairs)] 
    return z 

def tag_str_2_id_list(tag_str_list, tag_2_id_dict):
    return [tag_2_id_dict[tag] for tag in tag_str_list]

def word_list_2_id_list(word_list, word_dict):
    id_list = []
    for word in word_list:
        if word in word_dict:
            id_list.append(word_dict[word])
        else:
#             print(word)
            id_list.append(word_dict['_OOV_'])    
    return id_list

def compute_prob_stage_2(model, claim_dict, doc_nr, line_nr):
    claims_word_list = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['word_list']
    hypothesis_word_list = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['word_list']
    claim_pos = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['tag_list']
    hypothesis_pos = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['tag_list']
    claim_oov = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['exact_match_list']
    hypothesis_oov = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['exact_match_list']
    
    premises = torch.tensor([claims_word_list]).to(device)
    premises_lengths = torch.tensor([len(claims_word_list)]).to(device)
    hypotheses = torch.tensor([hypothesis_word_list]).to(device)
    hypotheses_lengths = torch.tensor([len(hypothesis_word_list)]).to(device)
    premises_part_of_speech = torch.tensor([claim_pos]).to(device)
    premises_part_of_speech_lengths = torch.tensor([len(claim_pos)]).to(device)
    premises_out_of_vocabulary = torch.tensor([claim_oov]).to(device)
    premises_out_of_vocabulary_lengths = torch.tensor([len(claim_oov)]).to(device)
    hypotheses_part_of_speech = torch.tensor([hypothesis_pos]).to(device)
    hypotheses_part_of_speech_lengths = torch.tensor([len(hypothesis_pos)]).to(device)
    hypotheses_out_of_vocabulary = torch.tensor([hypothesis_oov]).to(device)
    hypotheses_out_of_vocabulary_lengths = torch.tensor([len(hypothesis_oov)]).to(device)
    
    _, probs = model(premises,
                    premises_lengths,
                    hypotheses,
                    hypotheses_lengths, 
                    premises_part_of_speech, 
                    premises_part_of_speech_lengths,
                    premises_out_of_vocabulary,
                    premises_out_of_vocabulary_lengths,
                    hypotheses_part_of_speech,
                    hypotheses_part_of_speech_lengths,
                    hypotheses_out_of_vocabulary,
                    hypotheses_out_of_vocabulary_lengths)
    return float(probs[0][1])

def compute_prob_stage_3(model, claim_dict, doc_nr, line_nr):
    claims_word_list = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['word_list']
    hypothesis_word_list = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['word_list']
    claim_pos = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['tag_list']
    hypothesis_pos = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['tag_list']
    claim_oov = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['exact_match_list']
    hypothesis_oov = claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['exact_match_list']
    
    premises = torch.tensor([claims_word_list]).to(device)
    premises_lengths = torch.tensor([len(claims_word_list)]).to(device)
    hypotheses = torch.tensor([hypothesis_word_list]).to(device)
    hypotheses_lengths = torch.tensor([len(hypothesis_word_list)]).to(device)
    premises_part_of_speech = torch.tensor([claim_pos]).to(device)
    premises_part_of_speech_lengths = torch.tensor([len(claim_pos)]).to(device)
    premises_out_of_vocabulary = torch.tensor([claim_oov]).to(device)
    premises_out_of_vocabulary_lengths = torch.tensor([len(claim_oov)]).to(device)
    hypotheses_part_of_speech = torch.tensor([hypothesis_pos]).to(device)
    hypotheses_part_of_speech_lengths = torch.tensor([len(hypothesis_pos)]).to(device)
    hypotheses_out_of_vocabulary = torch.tensor([hypothesis_oov]).to(device)
    hypotheses_out_of_vocabulary_lengths = torch.tensor([len(hypothesis_oov)]).to(device)
    
    _, probs = model(premises,
                    premises_lengths,
                    hypotheses,
                    hypotheses_lengths, 
                    premises_part_of_speech, 
                    premises_part_of_speech_lengths,
                    premises_out_of_vocabulary,
                    premises_out_of_vocabulary_lengths,
                    hypotheses_part_of_speech,
                    hypotheses_part_of_speech_lengths,
                    hypotheses_out_of_vocabulary,
                    hypotheses_out_of_vocabulary_lengths)
    return [float(score) for score in probs[0]]

# %%
from utils_db import dict_load_json
from doc_results import Claim
from claim_database_stage_2_3 import get_word_tag_list_from_text
from claim_database_stage_2_3 import hypothesis_evidence_2_index



claim_nr = 12
line_nr = 0
nr_in_doc_selected_list = 0

path_claim = os.path.join(path_dir_doc_selected, 'claims_dev', str(claim_nr) + '.json')
claim_dict = dict_load_json(path_claim)
doc_nr = claim_dict['docs_selected'][nr_in_doc_selected_list]

line_list = wiki_database.get_lines_from_id(doc_nr)
nr_lines = len(line_list)
line_text = line_list[line_nr]

claim = Claim(claim_dict)
claim_text = claim.claim

# === process word tags and word list === #
tag_list_claim, word_list_claim = get_word_tag_list_from_text(text_str = claim_text, 
                                                              nlp = nlp, 
                                                              method_tokenization_str = method_tokenization)

# === process word tags and word list === #
tag_list_line, word_list_line = get_word_tag_list_from_text(text_str = line_text, 
                                                              nlp = nlp, 
                                                              method_tokenization_str = method_tokenization)

claim_dict['document_retrieval'] = {}
if doc_nr not in claim_dict['document_retrieval']:
    claim_dict['document_retrieval'][doc_nr] = {}
    
if str(line_nr) not in claim_dict['document_retrieval'][doc_nr]:
    claim_dict['document_retrieval'][doc_nr][str(line_nr)] = {}

if 'claim' not in claim_dict['document_retrieval'][doc_nr][str(line_nr)]:
    claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim'] = {}

if 'document' not in claim_dict['document_retrieval'][doc_nr][str(line_nr)]:
    claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document'] = {}
    
claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['tag_list'] = [17] + tag_str_2_id_list(
    tag_list_claim, tag_2_id_dict) + [17]
claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['word_list'] = word_list_2_id_list(
    ["_BOS_"] + word_list_claim + ["_EOS_"], word_dict)
claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['tag_list'] = [17] + tag_str_2_id_list(
    tag_list_line, tag_2_id_dict) + [17]
claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['word_list'] = word_list_2_id_list(
    ["_BOS_"] + word_list_line + ["_EOS_"], word_dict)

ids_document, ids_claim = hypothesis_evidence_2_index(hypothesis = word_list_line,
                           premise = word_list_claim,
                           randomise_flag = False)

claim_dict['document_retrieval'][doc_nr][str(line_nr)]['claim']['exact_match_list'] = [0] + ids_claim + [1]
claim_dict['document_retrieval'][doc_nr][str(line_nr)]['document']['exact_match_list'] = [0] + ids_document + [1]

prob = compute_prob_stage_2(model, claim_dict, doc_nr, line_nr)
print(prob, word_list_line, word_list_claim)
# Out:
# tensor([6], device='cuda:0') tensor([6], device='cuda:0') tensor([6], device='cuda:0')
# tensor([[0.8663, 0.1337]], device='cuda:0', grad_fn=<SoftmaxBackward>) ['Single', '-', 'ended', 'may', 'refer', 'to', ':'] ['the', 'Cretaceous', 'ended', '.']

# %%
import torch
from esim.model import ESIM
import pickle

path_word_dict = os.path.join('/mnt/01_thesis/01_code/ESIM/data/preprocessed/FEVER_stage_2', 'worddict.pkl')
word_dict = pickle.load( open( path_word_dict, "rb" ) )

# stage 2
path_stage_2_model = '/mnt/01_thesis/01_code/ESIM/data/checkpoints/FEVER_stage_2_pos_oov/esim_2.pth.tar'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

checkpoint = torch.load(path_stage_2_model)

# Retrieving model parameters from checkpoint.
vocab_size = checkpoint["model"]["_word_embedding.weight"].size(0)
embedding_dim = checkpoint["model"]['_word_embedding.weight'].size(1)
hidden_size = checkpoint["model"]["_projection.0.weight"].size(0)
num_classes = checkpoint["model"]["_classification.4.weight"].size(0)

model = ESIM(vocab_size,
             embedding_dim,
             hidden_size,
             num_classes=num_classes,
             use_pos_tag_flag=1,
             use_oov_flag=1,
             device=device).to(device)

model.load_state_dict(checkpoint["model"])

model.eval()
# Out:
# ESIM(
#   (_word_embedding): Embedding(38559, 300, padding_idx=0)
#   (_rnn_dropout): RNNDropout(p=0.5)
#   (_encoding): Seq2SeqEncoder(
#     (_encoder): LSTM(394, 300, batch_first=True, bidirectional=True)
#   )
#   (_attention): SoftmaxAttention()
#   (_projection): Sequential(
#     (0): Linear(in_features=2400, out_features=300, bias=True)
#     (1): ReLU()
#   )
#   (_composition): Seq2SeqEncoder(
#     (_encoder): LSTM(300, 300, batch_first=True, bidirectional=True)
#   )
#   (_classification): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=2400, out_features=300, bias=True)
#     (2): Tanh()
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=300, out_features=2, bias=True)
#   )
# )

# %%
from claim_database_stage_2_3 import hypothesis_evidence_2_index

ids_hypothesis, ids_evidence = hypothesis_evidence_2_index(hypothesis = word_list_line,
                           premise = word_list_claim,
                           randomise_flag = False)

# %%
from utils_db import get_file_name_from_variable_list

embeddings_settings_sentence_retrieval_list = []
embeddings_settings_label_prediction_list = []

path_base_dir = 'tmp'
path_document_retrieval_dir = os.path.join(path_base_dir, get_file_name_from_variable_list('document_retrieval'))
path_sentence_retrieval_dir = os.path.join(path_base_dir, 'sentence_retrieval')
path_label_prediction_dir = os.path.join(path_base_dir, 'label_prediction')

for embeddings_setting in embeddings_settings_sentence_retrieval_list:
    path_sentence_retrieval_dir = get_file_name_from_variable_list(path_sentence_retrieval_dir, embeddings_setting)

for embeddings_setting in embeddings_settings_label_prediction_list:
    path_label_prediction_dir = get_file_name_from_variable_list(path_label_prediction_dir, embeddings_setting)

path_settings_dict = os.path.join(path_base_dir)

# %%
# A copy claims include document_retrieval[docs][lines] = ...
# Include sentence_retrieval[docs][lines] = prediction
# Include sentence_retrieval['selected'][docs][lines]
# Include label_prediction['predicted_value']

# %%
from utils_db import dict_load_json
from doc_results import Claim

method_tokenization = 'tokenize_text_pos'
doc_nr = 1
line_nr = 1
claim_nr = 4


line_list = wiki_database.get_lines_from_id(doc_nr)

line_text = line_list[line_nr]


claim = claim_database.get_claim_from_id(claim_nr)
claim = Claim(claim)
claim_text = claim.claim
claim_text


setup_document_retrieval = 1
setup_sentence_retrieval = 1
setup_label_prediction = 1

path_dir_doc_selected = '/home/bmelman/Desktop/C_disk/02_university/06_thesis/01_code/fever/_04_results/vocab_title_1_t/thr_0.01_/ex_term_frequency_inverse_document_frequency_title/results_experiment_dev_tf_idf_normalise_5'

claim_nr = 1

# === stage 1 === #
path_claim = os.path.join(path_dir_doc_selected, 'claims', str(claim_nr) + '.json')
claim_dict = dict_load_json(path_claim)
claim_dict['claim_word_list']
claim_dict['claim_tag_list']
doc_nr = 1

tag_list_claim, word_list_claim = get_word_tag_list_from_text(text_str = claim_text, 
                                                              nlp = nlp, 
                                                              method_tokenization_str = method_tokenization)
claim_dict['documents']['word_list'][str(doc_nr)][str(line_nr)] = 
claim_dict['documents']['tag_list'][str(doc_nr)][str(line_nr)] =

# %%
from sqlitedict import SqliteDict
import sqlite3
import spacy


dir_db = 'tmp'
path_database = os.path.join(dir_db, 'wiki_tag_oov.db')

for doc_nr in range(nr_wiki_pages):
    wiki_database.id_2_lines_db(doc_nr)

# %%
nr_doc = 2600012
wiki_database.get_title_from_id(nr_doc)

# %%
{'id': 105077, 'verifiable': 'VERIFIABLE', 'label': 'REFUTES', 'claim': 'The Daily Show is incapable of being satire focused.', 'evidence': [[[123389, 137838, 'The Daily Show', 0]], [[123389, 137839, 'The Daily Show', 2]]]}
# Out:
# {'id': 105077,
#  'verifiable': 'VERIFIABLE',
#  'label': 'REFUTES',
#  'claim': 'The Daily Show is incapable of being satire focused.',
#  'evidence': [[[123389, 137838, 'The Daily Show', 0]],
#   [[123389, 137839, 'The Daily Show', 2]]]}

# %%
from utils_doc_results import Claim
nr_claims = claim_database.settings['nr_claims']
list_long_claims = []
for claim_nr in range(nr_claims):
    claim = Claim(claim_database.get_claim_from_id(claim_nr))
    for annotator in claim.evidence:
        if len(annotator) > 40:
            list_long_claims.append(claim_database.get_claim_from_id(claim_nr))

# %%
claim = Claim(claim_database.get_claim_from_id(5))
len(claim.evidence)

# %%
list_long_claims[0]

# %%
list_tmp = []
for claim in list_long_claims:
    for annotator in claim.evidence:
        if len(annotator)>40:
            print(len(annotator))
            list_tmp.append(claim)

# %%
list_tmp[0].evidence

# %%
from doc_results import Claim
from claim_database_stage_2_3 import get_word_tag_list_from_text

method_tokenization = 'tokenize_text_pos'
doc_nr = 1
line_nr = 1
claim_nr = 4


line_list = wiki_database.get_lines_from_id(doc_nr)

line_text = line_list[line_nr]


claim = claim_database.get_claim_from_id(claim_nr)
claim = Claim(claim)
claim_text = claim.claim
claim_text

tag_list_claim, word_list_claim = get_word_tag_list_from_text(text_str = claim_text, 
                                                              nlp = nlp, 
                                                              method_tokenization_str = method_tokenization)

tag_list_line, word_list_line = get_word_tag_list_from_text(text_str = line_text, 
                                                              nlp = nlp, 
                                                              method_tokenization_str = method_tokenization)


# list_splitted_text = 
# list_pos_tags = 
# list_oov_index =

# %%
class PerformanceEntireSystem:
    def __init__(self, ):
        self.base_dir = 'tmp'
        self.nlp = spacy.load('en', disable=["parser", "ner"])
        self.nr_claims = 20000

# %%
from utils_db import dict_load_json

setup_document_retrieval = 1
setup_sentence_retrieval = 1
setup_label_prediction = 1
path_dir_doc_selected = '/home/bmelman/Desktop/C_disk/02_university/06_thesis/01_code/fever/_04_results/vocab_title_1_t/thr_0.01_/ex_term_frequency_inverse_document_frequency_title/results_experiment_dev_tf_idf_normalise_5'

claim_nr = 1

# === stage 1 === #
path_claim = os.path.join(path_dir_doc_selected, 'claims', str(claim_nr) + '.json')
claim_dict = dict_load_json(path_claim)
claim_dict['claim_word_list']
claim_dict['claim_tag_list']
doc_nr = 1

tag_list_claim, word_list_claim = get_word_tag_list_from_text(text_str = claim_text, 
                                                              nlp = nlp, 
                                                              method_tokenization_str = method_tokenization)
claim_dict['documents']['word_list'][str(doc_nr)][str(line_nr)] = 
claim_dict['documents']['tag_list'][str(doc_nr)][str(line_nr)] = 

# === stage 2 === #
# add ranking 
# selection ids

# === stage 3 === #
# predicted label per sentence
# final label
# Out:
#   File "<ipython-input-5-3d23026512d8>", line 15
#     claim_dict['documents']['word_list'][str(doc_nr)][str(line_nr)] =
#                                                                       ^
# SyntaxError: invalid syntax

# %%
from wiki_database import Text
line_nr = 1
line_text = line_list[line_nr]; 
line = Text(line_text)
line.process(['tokenize'])

# %%
with SqliteDict(path_database) as dict_db:

# %%
from utils_doc_results import ClaimDatabase


path_raw_data = os.path.join(config.ROOT, config.DATA_DIR, config.RAW_DATA_DIR)
path_dir_claim_database = os.path.join(config.ROOT, config.DATA_DIR, config.DATABASE_DIR)

claim_data_set = 'train'

K = 5
claim_database = ClaimDatabase(path_dir_database = path_dir_claim_database, 
                               path_raw_data = path_raw_data, 
                               claim_data_set = claim_data_set, 
                               K = K)
